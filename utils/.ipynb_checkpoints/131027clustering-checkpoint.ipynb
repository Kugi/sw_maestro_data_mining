# %%
import pgdb
import pandas
import pickle
from pandas import DataFrame, Series

# %% [markdown]
# 데이터베이스에서 유효하다고 보이는 앱들의 PMI 값을 가져온다.<br>
# 앱 이름(app_name)에 ampersand(&)나 sharp(#)가 포함되어 있으면 부적절한 결과가 나오는 것으로 보인다.

# %%
#db = pgdb.connect(database="application",host="soma3.buzzni.com:5432",user="soma",password="maestro@)!#")
#entity_pmi_table = pandas.io.sql.read_frame('select * from app_keyword_pmi',db)

db = pgdb.connect(database="application",host="soma3.buzzni.com:5432",user="soma",password="maestro@)!#")
#entity_pmi_table = pandas.io.sql.read_frame("select * from app_keyword_pmi where pmi != 0 order by pmi desc", db)
entity_pmi_table = pandas.io.sql.read_frame("select * from app_keyword_pmi where pmi != 0 and app_name not like '%&%' and app_name not like '%#%' order by pmi desc", db)
#entity_pmi_table = pickle.load(file('./entity_pmi_table.df'))

# %%
entity_pmi_table.to_pickle("entity_pmi_table_final.df")
entity_pmi_table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 358153 entries, 0 to 358152
# Data columns (total 4 columns):
# app_name       358153  non-null values
# keyword        358153  non-null values
# pmi            358153  non-null values
# update_date    358153  non-null values
# dtypes: float64(1), object(3)

# %%
entity_pmi_table.head()
# Out:
#                     app_name keyword      pmi update_date
# 0              "Daily Perks"   "타이쿤"  10.3148  2013-10-19
# 1               "렙업만이살길 _게임"   "타이쿤"  10.3148  2013-10-19
# 2                "프리티 펫 타이쿤"   "타이쿤"  10.3148  2013-10-19
# 3      "Memoires: The Diary"   "타이쿤"  10.3148  2013-10-19
# 4  "Commando - Final Battle"   "타이쿤"  10.3148  2013-10-19

# %% [markdown]
# 데이터베이스에서 얻어온 유효한 데이터들의 앱 갯수는 다음과 같다.

# %%
names = []
namescnt = {}

for idx, value in entity_pmi_table.iterrows():

    tempstr = value['app_name']
    tempstr = tempstr.replace('"', "")
    if namescnt.has_key(tempstr):
        namescnt[tempstr] += 1
    else:
        namescnt[tempstr] = 0
    try:
        names.remove(tempstr)
    except:
        pass
    names.append(tempstr)
    #if zz >= 50:
    #    break;
        
#print '\n'.join(names)
len(names)
# Out:
# 6470

# %% [markdown]
# 50개 이상의 키워드에 대한 PMI 값이 존재하는 앱만을 뽑아낸다.

# %%
valuableApps = []
for k, v in namescnt.iteritems():
    if v > 50:
        valuableApps.append(k)

len(valuableApps)
# Out:
# 2766

# %% [markdown]
# 전체 키워드를 불러온다.

# %%
def load(fname):
    ''' load the file using std open'''
    f = open(fname,'r')

    data = []
    for line in f.readlines():
        #print line
        data.extend(line.replace('\n','').replace('﻿', '').split(', '))
    
    f.close()

    return data

keyword = load('../utils/data/Keyword.txt')
print " ".join(keyword)
# Out:
# 퍼즐 캐주얼 아케이드 여성 남성 친구 연애 연예 얼굴 속도 돈 랜덤 random 음식 방법 안드로이드 아이폰 android iphone 오락 심리 부자 영어 토익 공부 일정 달력 계획 공략 레이싱 RPG 카드 디펜스 두뇌 시뮬 달리기 슈팅 축구 경영 타이쿤 탈출 추리  장기 비행기 사천성 스포츠 농구 낚시 음악 카톡 골프 당구 야구 볼링 삼국지 전쟁 건강 운동 교육 교통 금융 날씨 뉴스 잡지 데코레이션 도구 도서 참고자료 라이브 배경화면 라이브러리 데모 라이프스타일 블로그 만화 미디어 동영상 비즈니스 편집 사진 생산성 소셜 콘텐츠 쇼핑 위젯 자동차 경주 다이어트 달력 생리 캘린더 사주팔자 궁합 체중 사전 컴퓨터 백과사전 급식 학교 초등학교 중학교 고등학교 대학교 Korea 네비게이션 지하철 종결자 내비 가계부 Money 스마트 계산기 은행 검색어 실시간 신문 클래식 애니 낚시 런처 주소록 폰 바이러스 보안 성경 찬송 바이블 백신 웹 스티커 사주 운세 코믹 3D 별자리 tool 웹툰 플레이어 카메라 벨소리 한글 오피스 office 알바 photo 드라이브 파일 갤러리 그룹 바코드 스캐너 소셜커머스 소셜 어른 노래 꾸미기 패션

# %% [markdown]
# 앱 이름을 인덱스로, 키워드를 칼럼으로 하는 데이터프레임을 만든다.<br>
# 테스트를 위해 사용할 갯수를 조절할 수 있다.

# %%
import numpy

#index = ['a', 'b', 'c']
index = valuableApps#[0:200]#[0:200]
dftemp = pandas.DataFrame(columns=keyword, index = index)
dftemp.loc[:,:] = 0
# print dftemp.columns
# dftemp.loc['류현진 배경화면','퍼즐'] = 0.9
dftemp.shape
# Out:
# (2766, 157)

# %% [markdown]
# 0으로 초기화된 데이터프레임에 PMI 값을 채워 넣는다.

# %%
tempstr = ''
#cntsuccess = 0
#cntfail = 0
count = 0
for idx, row in entity_pmi_table.iterrows():
    _pmi = row['pmi']
    _appname = row['app_name'].replace('"', '').replace('﻿', '')
    _keyword = row['keyword'].replace('"', '').replace('﻿', '')
    
    try:
        dftemp.ix[_appname, _keyword] = _pmi
        if idx < 20:
            print idx, _appname, _keyword, _pmi
        #break
        #ntsuccess+=1
        count+=1
        
    except Exception, e:
        #print "fail:: ", ' '.join(e), _keyword, _pmi
        #cntfail+=1
        #break;
        pass
        
    #if ( idx > 100 ):
    #    break;
print 'done', count
print idx
# Out:
# 13 초코초코타이쿤 타이쿤 10.3108858221
# done
#  285236
# 358152

# %%
#dftemp.keys()

# %% [markdown]
# 입력된 데이터를 눈으로 확인하고 싶다면 다음과 같이 한다.

# %%
dftemp[0:10]['노래']
# Out:
#                                        노래
# Yahoo! Mail                    -0.3029168
# News Republic                    1.638655
# FINAL FANTASY DIMENSIONS        0.9201899
# Jota Text Editor                 1.390194
# Roman Empire                     1.305816
# Telefe                           1.350973
# 제노니아5                           -0.560562
# 무한 레이싱                          0.9714832
# FINAL FANTASY AIRBORNE BRIGADE          0
# 아쿠의 퍼즐패밀리 for Kakao                     0

# %%
dftemp.ix['무한 레이싱']['음악']
# Out:
# 2.1646480843632

# %%
dftemp.ix['무한 레이싱']
# Out:
# 퍼즐                 0
# 캐주얼                0
# 아케이드        5.829084
# 여성          2.030965
# 남성          1.701544
# 친구          1.887312
# 연애          2.859262
# 연예                 0
# 얼굴       -0.00520741
# 속도           4.55722
# 돈           1.480758
# 랜덤          5.076401
# random             0
# 음식           1.11996
# 방법          2.182495
# ...
# office            0
# 알바                0
# photo             0
# 드라이브              0
# 파일         2.363577
# 갤러리               0
# 그룹                0
# 바코드               0
# 스캐너               0
# 소셜커머스             0
# 소셜         3.220041
# 어른                0
# 노래        0.9714832
# 꾸미기               0
# 패션         1.450289
# Name: 무한 레이싱, Length: 157, dtype: object

# %%
### i 값을 바꾸면 원하는 앱의 키워드별 PMI를 모두 볼 수 있다. ###
#i = 1
#d = dftemp[i:i+1]
#print d.index
#for key, pmi in zip(d.columns, d.values[0]):
#    print key, pmi

# %%
dftemp.shape
# Out:
# (2766, 157)

# %% [markdown]
# DBSCAN으로 클러스터링을 시도해본다.

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['load', 'e']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
dftemphead = dftemp
dftemphead = StandardScaler().fit_transform(dftemphead)
print 'dftemphead.shape:', dftemphead.shape
# Out:
# dftemphead.shape: (2766, 157)
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.py:278: UserWarning: StandardScaler assumes floating point values as input, got object
#   "got %s" % (estimator, X.dtype))

# %%
##############################################################################
# Compute DBSCAN
dbscan = DBSCAN().fit(dftemphead)
core_samples = dbscan.core_sample_indices_
labels = dbscan.labels_
core_samples
# Out:
# []

# %%
labels
# Out:
# array([-1., -1., -1., ..., -1., -1., -1.])

# %%
from sklearn.externals import joblib
#joblib.dump(dbscan, '../data/my_model01.pkl', compress=9)
#model_clone = joblib.load('my_model.pkl')

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

##############################################################################
# Plot result
import pylab as pl


# Black removed and is used for noise instead.
unique_labels = set(labels)

unique_labels
# Out:
# {-1.0}

# %%
colors = pl.cm.Spectral(numpy.linspace(0, 1, len(unique_labels)))

#pl.xlim(xmin=-4, xmax=4)
#pl.ylim(ymin=-4, ymax=4)

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'
        markersize = 6
    class_members = [index[0] for index in numpy.argwhere(labels == k)]
    cluster_core_samples = [index for index in core_samples
                            if labels[index] == k]
    for index in class_members:
        x = dftemphead[index]
        #x?
        if index in core_samples and k != -1:
            markersize = 14
        else:
            markersize = 6
        pl.plot(x[0], x[1], 'o', markerfacecolor=col,
                markeredgecolor='k', markersize=markersize)

# %% [markdown]
# PCA를 통해 2차원으로 바꾼 후 시도하면 어떨까.

# %% [markdown]
# 아래는 분산도 그래프를 그리는 함수이다.

# %%
from itertools import cycle

def plot_2D(data, target, target_names):
    colors = cycle('rgbcmykw')
    target_ids = range(len(target_names))
    pl.figure()
    for i, c, label in zip(target_ids, colors, target_names):
        pl.scatter(data[target == i, 0], data[target == i, 1],
                   c=c, label=label)
    pl.legend()

# %% [markdown]
# n_components를 달리 하며 보자.

# %%
pca = PCA(n_components=2, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 2)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 808 ms, sys: 0 ns, total: 808 ms
# Wall time: 806 ms

# %%
pca = PCA(n_components=3, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 3)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 768 ms, sys: 0 ns, total: 768 ms
# Wall time: 770 ms

# %%
pca = PCA(n_components=4, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 4)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 668 ms, sys: 0 ns, total: 668 ms
# Wall time: 669 ms

# %% [markdown]
# n_components가 5가 되자 뭔가 분류가 된 것 처럼 보인다.<br>
# 5보다 더 큰 수를 넣었을 때는 점차 의미가 사라지는 것 같다.

# %%
pca = PCA(n_components=5, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 5)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 452 ms, sys: 0 ns, total: 452 ms
# Wall time: 451 ms

# %%
dbscan2.components_
# Out:
# array([[ 0.68517899,  0.75246042, -1.35565078, -1.13044666,  0.00614517],
#        [ 0.69024124,  0.50359184, -1.31068655, -1.39485163, -0.13894193],
#        [ 0.61856678,  0.84110731, -1.17857573, -0.84196763, -0.07557847],
#        ...,
#        [-1.46612216,  1.51937785,  0.36690353,  0.40631551,  0.90647318],
#        [ 1.14774859,  0.79722779,  1.39014107, -0.33167838,  0.39924037],
#        [ 0.15512223, -1.20299314,  0.52909771, -0.12283158, -0.35431432]])

# %%
pca = PCA(n_components=6, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 6)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 388 ms, sys: 0 ns, total: 388 ms
# Wall time: 390 ms

# %%
pca = PCA(n_components=7, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 7)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 380 ms, sys: 0 ns, total: 380 ms
# Wall time: 380 ms

# %%
pca = PCA(n_components=8, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 8)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 380 ms, sys: 0 ns, total: 380 ms
# Wall time: 383 ms

# %% [markdown]
# 9부터는 아무런 분류도 볼 수 없다.

# %% [markdown]
# 의미를 파악하려면 어떻게 해야 하는지는 잘 모르겠다.<br>
# 이번에는 PMI가 140개 이상의 키워드에 대해 존재하는 앱들만을 클러스터링 해 보자.

# %%
valuableApps140 = []
for k, v in namescnt.iteritems():
    if v > 140:
        valuableApps140.append(k)

print len(valuableApps140)

index = valuableApps140#[0:200]#[0:200]
dftemp2 = pandas.DataFrame(columns=keyword, index=index)
dftemp2.loc[:,:] = 0
print dftemp2.shape


count = 0
for idx, row in entity_pmi_table.iterrows():
    _pmi = row['pmi']
    _appname = row['app_name'].replace('"', '').replace('﻿', '')
    _keyword = row['keyword'].replace('"', '').replace('﻿', '')
    
    try:
        dftemp2.ix[_appname, _keyword] = _pmi
        if idx < 20:
            print idx, _appname, _keyword, _pmi
        count+=1
        
    except Exception, e:
        #print "fail:: ", ' '.join(e), _keyword, _pmi
        pass
        
print 'done', count
# Out:
# 597
# (597, 157)
# done
#  89261

# %%
dftemphead2 = dftemp2
dftemphead2 = StandardScaler().fit_transform(dftemphead2)
print 'dftemphead.shape:', dftemphead.shape

# Compute DBSCAN
dbscan = DBSCAN().fit(dftemphead2)
core_samples = dbscan.core_sample_indices_
labels = dbscan.labels_
core_samples

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

unique_labels = set(labels)

colors = pl.cm.Spectral(numpy.linspace(0, 1, len(unique_labels)))

#pl.xlim(xmin=-4, xmax=4)
#pl.ylim(ymin=-4, ymax=4)

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'
        markersize = 6
    class_members = [index[0] for index in numpy.argwhere(labels == k)]
    cluster_core_samples = [index for index in core_samples
                            if labels[index] == k]
    for index in class_members:
        x = dftemphead2[index]
        #x?
        if index in core_samples and k != -1:
            markersize = 14
        else:
            markersize = 6
        pl.plot(x[0], x[1], 'o', markerfacecolor=col,
                markeredgecolor='k', markersize=markersize)
# Out:
# dftemphead.shape: (2766, 157)

# %%
pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 2)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 164 ms, sys: 0 ns, total: 164 ms
# Wall time: 163 ms

# %%
pca = PCA(n_components=3, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 3)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 152 ms, sys: 0 ns, total: 152 ms
# Wall time: 150 ms

# %%
pca = PCA(n_components=4, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 4)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 104 ms, sys: 0 ns, total: 104 ms
# Wall time: 102 ms

# %%
pca = PCA(n_components=5, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 5)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 84 ms, sys: 0 ns, total: 84 ms
# Wall time: 84.4 ms

# %% [markdown]
# 6부터는 아무런 분류가 되지 않는다.

# %% [markdown]
# 큰 차이는 없는 것 같다.<br>
# 다른 클러스터링 알고리즘을 적용하면 어떨까.<br>
# <br>
# 먼저 K-means 알고리즘을 사용해보자.

# %%
from sklearn.cluster import KMeans

# %%
nClusters = 5

kms = KMeans(n_clusters=nClusters)
kms.fit(dftemphead2)

#print kms.cluster_centers_
#print kms.labels_[:nClusters]

plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.

# %%
nClusters = 25

dftemphead3 = dftemphead;
vApps = valuableApps

print len(vApps)

#kms = KMeans(n_clusters=nClusters)
#kms.fit(dftemphead3)

#print kms.cluster_centers_
#print kms.labels_[:nClusters]

#plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead3)
df_pca = pca.transform(dftemphead3)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

# print kms2.cluster_centers_
# print kms2.labels_

# print '\n'.join(valuableApps140)
cluster_result = zip(vApps, kms2.labels_)
# print cluster_result
cluster_dict = {}
for name, c_id in cluster_result:
    if not cluster_dict.has_key(c_id):
        cluster_dict[c_id] = []
    cluster_dict[c_id].append(name)
# print dftemphead2
c_ids = cluster_dict.keys()
c_ids.sort()
for c_id in c_ids:
    print "#"*100
    for name in cluster_dict[c_id]:
        print "\t",c_id,"\t", name
        
plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.
# Out:
# 2766
# ####################################################################################################
# 	0 	News Republic
# 	0 	Drum Set
# 	0 	Egg Baby
# 	0 	Tower Blocks
# 	0 	Weatherwise
# 	0 	Pandora
# 	0 	Santa's Village
# 	0 	Drinking Games
# 	0 	Desert Eagle
# 	0 	Skater Boy
# 	0 	Love Tester
# 	0 	Walgreens
# 	0 	Happy Street
# 	0 	Paintball
# 	0 	HappyFish
# 	0 	블레이드 마스터
# 	0 	rad.io
# 	0 	듀얼오브페이트
# 	0 	Mob Wars
# 	0 	성냥 퍼즐
# 	0 	달려라! 마블 for Kakao
# 	0 	Geared
# 	0 	Tiny Village
# 	0 	매치업
# 	0 	웨딩 액자
# 	0 	TV.com
# 	0 	Elements
# 	0 	메탈슬러그
# 	0 	Plus500
# 	0 	Formspring
# 	0 	MARCA.com
# 	0 	Sky Go
# 	0 	초코초코타이쿤
# 	0 	The Motley Fool
# 	0 	2013프로야구
# 	0 	스윗가든
# 	0 	Modern Conflict
# 	0 	축구 2012
# 	0 	Word Search Puzzle
# 	0 	Qype
# 	0 	Eurosport.com
# 	0 	2012프로야구 KBO
# 	0 	AS.com
# 	0 	Run Like Hell!
# 	0 	Pyramid Rising
# 	0 	Onion News Network
# 	0 	혈십자
# 	0 	Rebuild
# 	0 	Top Girl
# 	0 	Hoopz
# 	0 	Your Orange
# 	0 	Monster Story™
# 	0 	다함께 쾅쾅쾅 for Kakao
# 	0 	Throwing Knife
# 	0 	Fancy
# 	0 	腾讯微博
# 	0 	Exchange Rates
# 	0 	4 Pics 1 Word
# 	0 	김기열의 인기없는 앱
# 	0 	Notes
# 	0 	Duck Hunter
# 	0 	Auto Plus
# 	0 	Overkill
# 	0 	BBC News
# 	0 	스쿨런: 질풍노도 여고생 for kakao
# 	0 	Jack'd
# 	0 	Cogs
# 	0 	Virtual Families
# 	0 	Magic Art
# 	0 	SMALL STREET
# 	0 	Hotel Tonight
# 	0 	좀비 타운
# 	0 	Little Empire
# 	0 	드림걸
# 	0 	Police Scanner
# 	0 	Bubbles
# 	0 	Lollipops
# 	0 	무한능력 눝! 시즌2
# 	0 	StumbleUpon
# 	0 	웃긴 사진
# 	0 	Strike Fighters
# 	0 	Drinking games
# 	0 	Swiped
# 	0 	버블 블레이즈
# 	0 	Free Running
# 	0 	Line Up
# 	0 	Darts
# 	0 	Universal Translator
# 	0 	디펜스테크니카
# 	0 	에어헌터 for Kakao
# 	0 	MercadoLibre
# 	0 	UFC TV
# 	0 	Heroes War™
# 	0 	Funny Jokes
# 	0 	Tic Tac Toe - 틱택토
# 	0 	모두의 연금술사 for Kakao
# 	0 	Veetle
# 	0 	심즈 프리플레이
# 	0 	Prayer Times
# 	0 	Thermal Camera
# 	0 	다같이 칼칼칼 for Kakao
# 	0 	YouTube
# 	0 	Street Racing
# 	0 	고양이전쟁
# 	0 	Draw!
# 	0 	공 튀기기
# 	0 	돼지러너 for Kakao
# 	0 	Monsters
# 	0 	Murder Room
# 	0 	Favorite Recipes
# 	0 	AnChan
# 	0 	Gang Wars
# 	0 	Preschool and Kindergarten
# 	0 	Bag It!
# 	0 	마왕전
# 	0 	배틀스쿨
# 	0 	소울 아일랜드
# 	0 	Univision
# 	0 	로스트 템플
# 	0 	TV 무료보기
# 	0 	Colors
# 	0 	Magic Trick
# 	0 	헬로키티 카페 (Hello Kitty Cafe)
# 	0 	Find The Ball
# 	0 	버섯전쟁
# 	0 	청풍명월 for Kakao
# 	0 	Total Recoil
# 	0 	100 Rooms
# 	0 	aPlayer
# 	0 	Space Hero
# 	0 	Goodreads
# 	0 	삼국대전
# 	0 	IKEA Catalogue
# ####################################################################################################
# 	1 	Jota Text Editor
# 	1 	avast! 모바일 백신
# 	1 	mSpot Music
# 	1 	Task Switcher
# 	1 	아스트로 파일 관리자
# 	1 	AudioManager
# 	1 	Battle.net 모바일 인증기
# 	1 	JustPictures!
# 	1 	Simple Calendar Widget
# 	1 	Dark Meadow: The Pact
# 	1 	BathingCat
# 	1 	Ruger - SR9
# 	1 	ConnectBot
# 	1 	AlarmDroid
# 	1 	RockPlayer Lite
# 	1 	BatteryLife
# 	1 	Zeam Launcher
# 	1 	Sipdroid
# 	1 	Full Screen Caller ID
# 	1 	Calendar Pad
# 	1 	Auto Memory Manager
# 	1 	Raging Thunder 2
# 	1 	Android Terminal Emulator
# 	1 	OneNote Mobile
# 	1 	WeatherBug
# 	1 	pooq for 안드로이드폰
# 	1 	PlayerPro Music Player
# 	1 	AutoCallRecorder
# 	1 	MultiPicture Live Wallpaper
# 	1 	Nova Launcher
# 	1 	Root Uninstaller
# 	1 	FMR Memory Cleaner
# 	1 	Google Play 북
# 	1 	Jewellust
# 	1 	AndExplorer
# 	1 	SketchBook Mobile
# 	1 	Pure Grid calendar widget
# 	1 	Music Hub
# 	1 	Citrix Receiver
# 	1 	MoboPlayer
# 	1 	BobClockD3
# 	1 	Pure messenger widget
# 	1 	Gesture Search
# 	1 	AirDroid
# 	1 	chompSMS
# 	1 	Root Explorer
# 	1 	Kies Air (키스 에어)
# 	1 	Poweramp Music Player (Trial)
# 	1 	RealCalc Scientific Calculator
# 	1 	Auto Call Recorder
# 	1 	AnTuTu Benchmark
# 	1 	MoreLocale 2
# 	1 	Wifi Fixer
# 	1 	Fast Web Installer
# 	1 	LauncherPro
# 	1 	LockBot Pro
# 	1 	응용 프로그램 보호
# 	1 	Google 지도 스트리트 뷰
# 	1 	Quadrant Standard Edition
# 	1 	ES Task Manager
# 	1 	Advanced Task Cleaner Pro
# 	1 	Task Manager
# 	1 	플래쉬라이트 - Tiny Flashlight ®
# 	1 	Grocery iQ
# 	1 	Unified Remote
# 	1 	DS audio
# 	1 	Moto X Mayhem Free
# 	1 	GO연락처
# 	1 	ADW.Launcher
# 	1 	Alarm Klock
# 	1 	Desktop VisualizeR
# 	1 	Google Play 무비
# 	1 	mVideoPlayer
# 	1 	Folder Organizer lite
# 	1 	ADWLauncher EX
# 	1 	DicePlayer
# 	1 	SwiftKey  키보드
# 	1 	Galactic Core Live Wallpaper
# 	1 	Widgetsoid
# 	1 	Act 1 Video Player
# 	1 	BT Wi-fi
# 	1 	Linpack for Android
# 	1 	Countdown Widget
# 	1 	Screen Off and Lock
# 	1 	MyBackup
# 	1 	android-vnc-viewer
# 	1 	Home Switcher
# 	1 	Google Chrome to Phone
# 	1 	더콜 스팸 전화번호부
# 	1 	Floating Image
# 	1 	SSI gTasks ToDo
# 	1 	Smart Keyboard PRO
# 	1 	File Explorer
# 	1 	Lock Screen Widget
# 	1 	Neocore
# 	1 	Mobile Security
# 	1 	DailyRoads Voyager
# 	1 	Battery Widget
# 	1 	Memory Trainer
# 	1 	Notification Toggle
# 	1 	Smart Shortcuts
# ####################################################################################################
# 	2 	오프라인 사전
# 	2 	배달의민족
# 	2 	김급식 - 전국 고등학교 급식 시간표 어플 유틸
# 	2 	Endomondo Sports Tracker
# 	2 	Dictionary.com
# 	2 	스마트롯데
# 	2 	비쥬얼드 for Kakao
# 	2 	SBS 고릴라
# 	2 	야후! 날씨
# 	2 	Elecont Weather Clock
# 	2 	사진 텍스트
# 	2 	핫메일
# 	2 	Google 어스
# 	2 	지하철 노선도
# 	2 	별자리표
# 	2 	twicca
# 	2 	생리 달력
# 	2 	Tv Mobile
# 	2 	네이버 - Naver
# 	2 	푸딩얼굴인식
# 	2 	꿀꿀이 가계부
# 	2 	IQ IQ 테스트
# 	2 	네이트만화
# 	2 	환율 계산기
# 	2 	인터넷 라디오
# 	2 	말하는 산타
# 	2 	스톱워치
# 	2 	통화 녹음
# 	2 	XE Currency
# 	2 	장난앱 - 친구에게 장난칠 때 필요한 최고의 어플!
# 	2 	매직데이
# 	2 	정통맞고 2012
# 	2 	전국버스
# 	2 	다국어 번역기
# 	2 	Sleep as Android Unlock
# 	2 	도전! 구구단
# 	2 	심볼즈
# 	2 	응급상황 대처방법
# 	2 	시크한 엄마의 요절복통 에피소드
# 	2 	여성생리달력/캘린더/생리일기
# 	2 	WhosHere
# 	2 	runtastic
# 	2 	비디오 플레이어
# 	2 	EBS 온에어
# 	2 	가짜 전화
# 	2 	코레일톡
# 	2 	언어 번역기
# 	2 	FatSecret의 칼로리 카운터
# 	2 	눔 다이어트 코치 (Noom)
# 	2 	단어 검색
# 	2 	고속도로교통정보
# 	2 	내 친구 찾기
# ####################################################################################################
# 	3 	스파이더 카드놀이
# 	3 	밧데리 - Battery
# 	3 	롯데닷컴(Lotte.com)
# 	3 	속도에 필요한
# 	3 	네이트
# 	3 	Yellow Pages
# 	3 	土豆
# 	3 	Sky+
# 	3 	Skyrock
# 	3 	NRJ
# 	3 	옥션
# 	3 	패션 스토리™
# 	3 	싸이워즈 for Kakao
# 	3 	스타샷
# 	3 	First Aid
# 	3 	핵전쟁 (Nuclear War)
# 	3 	大众点评
# 	3 	PhotoMontage
# 	3 	도전 1000곡 for Kakao
# 	3 	XING
# 	3 	GS SHOP
# 	3 	Fishing Diary
# 	3 	NDTV
# 	3 	Bartender
# 	3 	Dolphin
# 	3 	Bank of America
# 	3 	Pilot!
# 	3 	매직트리
# 	3 	Zoo Story
# 	3 	클레이랜드 for Kakao
# 	3 	WiMP
# 	3 	Sam's Club
# 	3 	Chess
# 	3 	MONOPOLY
# 	3 	모아모아용 for Kakao
# 	3 	United Airlines
# 	3 	캡
# 	3 	Bingo
# 	3 	곰TV
# 	3 	이모티콘
# 	3 	Slice (슬라이스)
# 	3 	11번가
# 	3 	Target
# 	3 	틀린그림찾기 !!!
# 	3 	ABC News
# 	3 	Metal Detector
# 	3 	해피포인트
# 	3 	Blink!Blink!Blink!
# 	3 	Dictionary
# 	3 	금이 화면
# 	3 	Fishing
# 	3 	Financial Times
# 	3 	QQ
# 	3 	빅뱅 셰이크
# 	3 	Argos
# 	3 	Photon
# 	3 	Durak+
# 	3 	7x7
# 	3 	Tesco
# 	3 	Sky News
# 	3 	wkw
# 	3 	Success Story
# 	3 	Assistant
# 	3 	대화를 번역
# 	3 	불가능한 게임
# 	3 	대전버스
# 	3 	피망 포커
# 	3 	Yahoo! JAPAN
# 	3 	Urban Dictionary
# 	3 	TED
# 	3 	스파이더 카드 놀이
# 	3 	Southwest Airlines
# 	3 	easyJet
# 	3 	온도 (온도계)
# 	3 	CVS/pharmacy
# 	3 	솔리테어
# 	3 	Theme Park
# 	3 	CAIXA
# 	3 	Yahoo!
# 	3 	la Caixa
# 	3 	Ocean Tower
# 	3 	도그파이트
# 	3 	NatWest
# 	3 	Backgammon
# 	3 	던전리그EX
# 	3 	리버시
# 	3 	Slot Machine +
# 	3 	Slot Machine
# 	3 	Bradesco
# 	3 	멜론
# 	3 	Teeter
# 	3 	BeeTV
# 	3 	GG
# 	3 	가상 수술
# 	3 	완벽한 피아노
# 	3 	Fly Delta
# 	3 	돋보기 / 확대경
# 	3 	가로세로 낱말맞추기2013
# 	3 	하트
# 	3 	HowStuffWorks
# 	3 	과일 링크
# 	3 	ICE
# 	3 	해피스트릿 for Kakao
# 	3 	Mileage
# 	3 	National Geographic
# 	3 	White Noise
# 	3 	Around the World in 80 Days
# 	3 	微博
# 	3 	MASH
# 	3 	Soccer
# 	3 	Shopper
# 	3 	탱그램
# 	3 	Airport City
# 	3 	Fab
# 	3 	10000000
# 	3 	연락처+
# 	3 	Banner
# ####################################################################################################
# 	4 	LOL백과사전
# 	4 	Flash Viewer
# 	4 	Kitchen Timer
# 	4 	Yelp
# 	4 	NoLED
# 	4 	WiFi Free
# 	4 	Parking Mania
# 	4 	국기 퀴즈
# 	4 	Stardunk
# 	4 	과일나라 앨리스 for Kakao
# 	4 	Fitbit
# 	4 	스피드 촬영
# 	4 	CSipSimple
# 	4 	lgCamera
# 	4 	던전앤소드 for Kakao
# 	4 	Tap the Frog
# 	4 	핀볼 게임 Pinball
# 	4 	Tap Ranch
# 	4 	The Moron Test
# 	4 	Spider Solitaire
# 	4 	아이들이 좋아하는 동영상 모음
# 	4 	iFighter 1945
# 	4 	WeeMee
# 	4 	스케치퀴즈
# 	4 	Instant Heart Rate - Pro
# 	4 	iTunes에서 검색
# 	4 	IM+ Pro
# 	4 	MoneyManager
# 	4 	3D Badminton
# 	4 	Kindle
# 	4 	HopStop
# 	4 	search.ch
# 	4 	WolframAlpha
# 	4 	Gobang
# 	4 	U+Box – for Kakao
# 	4 	Rule the Sky
# 	4 	FatBooth
# 	4 	스타일리시 스프린트
# 	4 	Air Penguin®
# 	4 	기타 튜너
# 	4 	Samsung Remote
# 	4 	Ringtone Maker
# 	4 	Farm Frenzy
# 	4 	아이러브커피 for Kakao
# 	4 	Racing Moto
# 	4 	Expedia Hotels
# 	4 	Explorer
# 	4 	Texas Poker
# 	4 	MP3 벨소리 메이커
# 	4 	London City Guide
# 	4 	Mega Jump
# 	4 	가상 기타
# 	4 	Reversi
# 	4 	속도계 - 비행자세계
# 	4 	Memo Pad
# 	4 	PayPal
# 	4 	4Sync
# 	4 	티티톡 - 무전기
# 	4 	Equalizer
# 	4 	ZOOMONEY(주머니)
# 	4 	Google+
# 	4 	짱라이브 jjanglive
# 	4 	네이버 미디어 플레이어
# 	4 	삼국지를 품다
# 	4 	Pocket God™
# 	4 	컴투스 홈런왕 for Kakao
# 	4 	Note Pad
# 	4 	yr.no
# 	4 	NBA GAME TIME
# 	4 	슬라이스 잇! (Slice It!)
# 	4 	Glympse
# 	4 	Pool Master
# 	4 	Magic Piano
# 	4 	Workout Trainer
# 	4 	LED Light
# 	4 	The Bard's Tale
# 	4 	Run (실행)
# 	4 	오븐브레이크
# 	4 	Epocrates
# 	4 	레츠골프 3
# 	4 	Orkut
# 	4 	신봉선맞고 시즌2
# 	4 	팔라독(Paladog)
# 	4 	아스팔트 6: 아드레날린
# 	4 	Mobile TV
# 	4 	커플 각서 (오빠믿지 종결자)
# 	4 	AOSS
# 	4 	Water Your Body
# 	4 	DB Navigator
# 	4 	Smax
# 	4 	Vignette
# 	4 	다번역성경찬송
# 	4 	MONOPOLY Hotels
# 	4 	사진 효과
# 	4 	Ninja Chicken
# 	4 	Supermarket Mania®
# 	4 	Calculator++
# 	4 	OpenTable
# 	4 	Geocaching
# 	4 	핀볼 (Pinball)
# 	4 	乗換案内
# 	4 	내 운동기록
# 	4 	지니톡(GenieTalk)
# 	4 	BBC iPlayer
# 	4 	AroundMe
# 	4 	Bubble Shooter
# 	4 	Zombies, Run!
# 	4 	Trial Xtreme 2
# 	4 	드래곤 플라이트 for Kakao
# 	4 	네이버 뮤직 - Naver Music
# 	4 	Cookie Dozer
# 	4 	CNET
# 	4 	삼국지 디펜스
# 	4 	Spy Camera
# 	4 	오타쿠 카메라
# 	4 	똥피하기 게임
# 	4 	다음 야구감독
# 	4 	Movie Maker를
# 	4 	TV를 무료로 시청
# 	4 	닌자가 되는 법
# 	4 	Game Dev Story
# 	4 	TweetCaster Pro for Twitter
# 	4 	아이폰 5 화면
# 	4 	Tangram HD
# 	4 	mobile9
# 	4 	Timer
# 	4 	카드가디언: 공주를 지켜줘 for kakao
# 	4 	1to50®
# 	4 	Urbanspoon
# 	4 	Tiny Tower
# 	4 	지문 인식 잠금
# 	4 	3D 낚시 게임
# 	4 	Cooking Dash
# 	4 	Coin Dozer
# 	4 	Photo Studio
# 	5 	The Sims™ FreePlay
# 	5 	러닝독 for Kakao
# 	5 	HBO GO
# 	5 	Can You Escape
# 	5 	삼국 이터니티
# 	5 	킹덤 앤 로드
# 	5 	on{X}
# 	5 	볼륨 부스터
# 	5 	Newton's Cradle
# 	5 	2011슈퍼사커
# 	5 	Angry Monkey
# 	5 	슬라임 대 버섯2
# 	5 	X Construction
# 	5 	Ingress
# 	5 	인디스트럭터블
# 	5 	모던 컴뱃 3: 몰락한 제국
# 	5 	City Jump
# 	5 	Nightclub Story™
# 	5 	Ducati Challenge
# 	5 	로스트 인 스타즈
# 	5 	Tap Pet Hotel
# 	5 	와일드 블러드
# 	5 	HexEditor
# 	5 	Bunny Shooter
# 	5 	Striker Soccer
# 	5 	로드 오브 나이츠
# ####################################################################################################
# 	6 	BW Animation Package
# 	6 	스카이 맵
# 	6 	Voice Recorder
# 	6 	한게임 런앤히트
# 	6 	SoundHound ∞
# 	6 	U+ 고객센터
# 	6 	Viber
# 	6 	Relax Melodies
# 	6 	Evernote
# 	6 	Shoot Bubble
# 	6 	TED Air
# 	6 	다음 사전 - Daum Dic
# 	6 	벨소리 메이커
# 	6 	HD Widgets
# 	6 	Christmas HD
# 	6 	WiFi Finder
# 	6 	Sleep as Android
# 	6 	비디오 채팅
# 	6 	Unit Converter
# 	6 	Simeji
# 	6 	네이트온톡
# 	6 	TuneIn Radio
# 	6 	1 - 클릭 청소기
# 	6 	NAVITIME
# 	6 	씽플레이어 가사지원 음악 플레이어
# 	6 	Adobe Photoshop Express
# 	6 	CamDictionary
# 	6 	알송 안드로이드
# 	6 	컬러 터치
# 	6 	음악 플레이어
# 	6 	SPB TV
# 	6 	WhatsApp Messenger
# 	6 	Paper Toss
# 	6 	Pocket Casts
# 	6 	runtastic PRO
# 	6 	사운드 레코더
# 	6 	Shazam
# 	6 	싸이메라 (Cymera) - 예뻐지는 카메라
# 	6 	알바천국 맞춤알바
# 	6 	4pda
# 	6 	有道词典
# 	6 	S Suggest
# 	6 	SoundHound
# 	6 	OTO(오티오) 무료국제전화
# 	6 	Instant Heart Rate
# 	6 	DailyHoroscope
# 	6 	말하는 고양이 톰 2
# 	6 	MapDroyd
# 	6 	PhotoWonder
# 	6 	정오의 데이트 - 매일 소개팅
# 	6 	Titanium Backup PRO Key ★ root
# 	6 	카카오앨범
# 	6 	이지 보이스 레코더
# 	6 	사운드슬립 음악치료
# 	6 	스마트청구서
# 	6 	바코드 스캐너
# 	6 	Pulse News
# 	6 	Steamy Window
# 	6 	네이버 블로그 - Naver Blog
# 	6 	gReader Pro (Google Reader)
# 	6 	Smart Office 2
# 	6 	NH 스마트뱅킹
# 	6 	오브제 OVJET
# 	6 	aniPet 수족관 라이브 배경화면
# 	6 	MX 플레이어 Pro
# 	6 	Google Goggles
# 	6 	AccuWeather Platinum
# 	6 	세이캐스트-무료음악감상
# 	6 	Relax and Sleep
# 	6 	모바일 안전결제(ISP)
# 	6 	챗온 ChatON
# 	6 	우리은행 원터치 개인
# 	6 	증권통
# 	6 	Wunderlist
# 	6 	Mindjet for Android
# 	6 	앱순이
# 	6 	CamCard (명함스캐너 한글 한자 일어 동시인식)
# 	6 	NH 나눔로또
# 	6 	Endomondo Sports Tracker PRO
# 	6 	CardStar
# 	6 	신개념 단축번호 노라조 2.0
# 	6 	살랑살랑 돛단배 (랜덤 채팅)
# 	6 	하나N Bank
# 	6 	카카오스토리 KakaoStory
# 	6 	버블 슛 (Bubble Shoot)
# 	6 	iTranslate
# 	6 	Wikitude
# 	6 	할인 계산기
# ####################################################################################################
# 	7 	삼성카드
# 	7 	Amazing Tattoo Ideas FREE
# 	7 	대한항공
# 	7 	의 알람 시계
# 	7 	말랑말랑 목장 for Kakao
# 	7 	오목+
# 	7 	나는꼼수다
# 	7 	메트로놈
# 	7 	اهم 1000 كلمة انجليزية
# 	7 	내 차
# 	7 	اهم 100 جملة انجليزية
# 	7 	시청 TV
# 	7 	위키백과사전
# 	7 	이것이 전쟁이다!
# 	7 	SBS 뉴스
# 	7 	크레이지 레이싱
# 	7 	골프스타
# 	7 	다음 - Daum
# 	7 	시간표
# 	7 	가로세로 낱말맞추기
# 	7 	라스트 삼국지 for Kakao
# 	7 	싸이월드
# 	7 	엠넷(Mnet)
# 	7 	폴라로이드 카메라
# 	7 	라인 LINE
# 	7 	지퍼(zipper)
# 	7 	오목
# 	7 	폰테마샵 키보드(스킨/테마/키패드)
# 	7 	발차기공주 돌격대
# 	7 	설명
# 	7 	USA TODAY
# 	7 	얼굴티비 for Kakao
# 	7 	수학 연습
# 	7 	메신저
# 	7 	개인 갤러리
# 	7 	말하는 개
# 	7 	GREE
# 	7 	솔리테어 Solitaire
# 	7 	MBC News
# 	7 	그림을 그릴
# 	7 	일기 예보
# 	7 	비디오
# 	7 	무료 영화
# 	7 	주기 표
# 	7 	운세 플러스
# 	7 	deciBel
# 	7 	360
# 	7 	손전등 ∞
# 	7 	에어 혼!
# 	7 	로봇 음성
# 	7 	어린이 게임
# 	7 	영화 퀴즈
# 	7 	IMoNi
# 	7 	우주 식민지
# 	7 	총
# 	7 	나침반
# 	7 	미로 게임
# 	7 	블랙리스트 (Blacklist)
# 	7 	피카코인 - 게임아이템 공짜로 즐겨라!
# 	7 	TV편성표
# 	7 	aQQ
# 	7 	손전등
# ####################################################################################################
# 	8 	Squats
# 	8 	Fresh Leaves
# 	8 	I Need A Hero
# 	8 	Super Photo
# 	8 	Spades!
# 	8 	Bible Verses
# 	8 	Tiny Bird
# 	8 	LINE WIND runner
# 	8 	Dragon Ball Z
# 	8 	모바일삼국지3
# 	8 	Crazy Running
# 	8 	andLess
# 	8 	[Adult Swim]
# 	8 	Obama VS Romney
# 	8 	Spades
# 	8 	사무라이 엠파이어
# 	8 	Sky Sports News
# 	8 	Euchre
# 	8 	Marktplaats
# 	8 	FPlayer
# 	8 	전쟁시대（Age of War）
# 	8 	신데렐라 카페
# 	8 	★디펜지 2★
# 	8 	Happy Jump
# 	8 	pixiv
# 	8 	Recipe Search
# 	8 	Inspirational Quotes
# 	8 	Akinator .
# 	8 	건물부수기
# 	8 	그레이프밸리
# 	8 	4 pics 1 word
# 	8 	몬스터 코인
# 	8 	Littlest Pet Shop
# 	8 	Fruit Roll
# 	8 	판타지크라이시스
# 	8 	Master DJ
# 	8 	Designs
# 	8 	Anger of Stick 2
# 	8 	Sing! Karaoke
# 	8 	Fishing Master
# 	8 	Goal.com
# 	8 	Phineas and Ferb
# 	8 	Radio Disney
# 	8 	갤럭시 엠파이어
# 	8 	삼국지 책략전
# 	8 	몬스터 블레이드
# 	8 	써니퍼피
# 	8 	The Right Mix
# 	8 	Fruited
# 	8 	Word Game
# 	8 	Tiny Tribe
# 	8 	Itaú
# 	8 	Note Me
# 	8 	MY LITTLE PONY
# 	8 	The CW Network
# 	8 	Al Jazeera English
# 	8 	Farm Up
# 	8 	좀비 스나이퍼
# 	8 	Terremoto!
# 	8 	GameFly
# 	8 	2014 World Cup
# 	8 	64 Games
# 	8 	SlenderMan
# 	8 	크루세이드 정벌기
# 	8 	60 Photos
# 	8 	탈출 게임 “Strange House”
# 	8 	My Horse
# 	8 	Tattoo Designs
# 	8 	Forest Life
# 	8 	Parking Car
# 	8 	Front Flip
# 	8 	detikcom
# 	8 	마비노기: 생활의 달인
# 	8 	Balda
# 	8 	Just Shout
# 	8 	이누야샤 완결편
# 	8 	Stick Fighter
# 	8 	100 Missions
# 	8 	My Horoscope
# 	8 	미니고치2
# 	8 	Alkitab
# 	8 	Space Jump
# 	8 	MY DRAGON
# 	8 	JAY Z Magna Carta
# 	8 	킥잇아웃!
# 	8 	US Newspapers
# 	8 	드래곤 스토리™
# 	8 	Car Parking
# 	8 	Rail Rush
# 	8 	Townsmen
# 	8 	배틀오디세이
# 	8 	Crazy Climber
# 	8 	드래곤 러쉬
# 	8 	SPORT.es
# 	8 	Funny Pics
# 	8 	LEGO® STAR WARS™
# 	8 	헬로키티 커피숍!
# 	8 	엘리오스의전설2
# 	8 	소울카드마스터4
# 	8 	Mandora
# ####################################################################################################
# 	9 	Aldiko Book Reader
# 	9 	모바일 T world
# 	9 	Flip - Silent
# 	9 	카메라 줌 FX
# 	9 	네이트온UC
# 	9 	ZEDGE™
# 	9 	WiFi Manager
# 	9 	HistoryEraser
# 	9 	Apps Organizer
# 	9 	GDocs
# 	9 	3G Watchdog
# 	9 	네이버 지도/교통 – Naver Map
# 	9 	Google 캘린더
# 	9 	WidgetLocker 잠금화면
# 	9 	N드라이브 - 사진 백업 - Naver Ndrive
# 	9 	Flikie Wallpapers HD
# 	9 	Skout - 채팅, 만남, 연애
# 	9 	CalenGoo
# 	9 	Note Everything
# 	9 	GO날씨EX
# 	9 	jjComics Viewer
# 	9 	GTasks
# 	9 	웹백신
# 	9 	Advanced Task Killer
# 	9 	네이버 웹툰 - Naver Webtoon
# 	9 	Ringdroid
# 	9 	Moon+ Reader
# 	9 	Guitar : Solo Lite
# 	9 	AudioManager Pro
# 	9 	WiFinder
# 	9 	BatteryTime Lite
# 	9 	컬러 터치 효과
# 	9 	애플리케이션 폴더
# 	9 	전화받자 스마트하게
# 	9 	VitalPlayer
# 	9 	Soul Movie
# 	11 	PhotoShake!
# 	11 	SoundBack
# 	11 	DiskUsage
# 	11 	Volume Control
# 	11 	SHADOWGUN
# 	11 	PicSay Pro - Photo Editor
# 	11 	Camera Fun Pro
# 	11 	Circle Battery Widget
# 	11 	SpeedX 3D
# 	11 	BeFunky Photo Editor
# 	11 	Traffic Monitor
# 	11 	Adobe AIR
# 	11 	AutoKiller Memory Optimizer
# 	11 	App Folder
# 	11 	Hungry Shark Free!
# 	11 	Google Voice
# 	11 	Riptide GP
# 	11 	aDownloader
# 	11 	IP Webcam
# 	11 	WiFi Scanner
# 	11 	Remote Mouse
# 	11 	Night Mode
# 	11 	Battery Info
# 	11 	Phantom Music Control
# 	11 	PhotoVault
# 	11 	Car Locator
# 	11 	Battle Bears
# 	11 	Hotspot Shield VPN
# 	11 	HDR Camera
# 	11 	Superuser
# 	11 	Link2SD
# 	11 	Speedx 3D
# 	11 	BusyBox Installer
# 	11 	퍼즐 주주 for Kakao
# 	11 	파일 엑스퍼트
# 	11 	Google 세상보기
# 	11 	Paint Pro
# 	11 	MultiLing 키보드
# 	11 	Milestone Overclock
# 	11 	Speedtest.net
# 	11 	Guerrilla Bob
# 	11 	Android Lost
# 	11 	Apex Launcher
# 	11 	Folder Player
# 	11 	doubleTwist Player
# 	11 	Battery Status
# 	11 	iStunt 2
# 	11 	지켜줘! 동물특공대 for Kakao
# 	11 	Video Live Wallpaper
# 	11 	테그라크 오버클럭 얼티밋
# 	11 	Simple Notepad
# 	11 	Guns'n'Glory
# 	11 	Remote Desktop Client
# 	11 	Firefox
# 	11 	Expensify
# 	11 	QR BARCODE SCANNER
# ####################################################################################################
# 	12 	배터리
# 	12 	변환기
# 	12 	RealPlayer®
# 	12 	줌 카메라
# 	12 	과학 계산기
# 	12 	이미지패러디
# 	12 	휴먼팩토리
# 	12 	신비하고 무서운 이야기
# 	12 	Sports Tracker
# 	12 	조용한 카메라
# 	12 	Tasker
# 	12 	Elixir 2
# 	12 	Google Reader
# 	12 	RunKeeper
# 	12 	Solitaire
# 	12 	애니팡 for Kakao
# 	12 	수평계
# 	12 	MOTP-Mobilians
# 	12 	Gmail
# 	12 	갤럭시
# 	12 	사진 합성
# 	12 	Foursquare
# 	12 	취업검색
# 	12 	다음 카페 - Daum Cafe
# 	12 	도니 캐시
# 	12 	말하는 고양이 톰
# 	12 	낯선 사람과의 대화 (랜덤 채팅)
# 	12 	사진 숨기기
# 	12 	PopSci.com
# 	12 	컴투스 맞고
# 	12 	로모 카메라
# 	12 	카메라 시작
# 	12 	현대카드(HyundaiCard)
# 	12 	에어펭귄
# 	12 	체커 (Checkers)
# 	12 	컬러 배경 화면
# 	12 	안티 모기
# 	12 	판도라TV
# 	12 	에브리온TV
# 	12 	淘宝
# 	12 	리틀레전드 for Kakao
# 	12 	Memory- 메모리 게임
# 	12 	AP 모바일
# 	12 	War 2 Victory
# 	12 	Nike+ Running
# 	12 	MP3 음악 다운로드
# 	12 	Tap Fish
# 	12 	GYRO
# 	12 	교통 통계
# 	12 	Place My Face
# 	12 	Tree Planet
# 	12 	WeChat
# 	12 	뷰티 카메라
# 	12 	가짜 아이폰
# 	12 	iQuarium
# 	12 	메모장
# 	12 	소울오브레전드
# 	12 	드래곤즈 오브 아틀란티스 : 용의 계승자들
# 	12 	한판맞고
# 	12 	Diner Dash
# 	12 	Ustream
# 	12 	미투데이 - me2day
# 	12 	기상청 날씨
# 	12 	카디오트레이너 CardioTrainer
# 	12 	스마트폰 중독 방지
# 	12 	라인 버즐
# 	12 	무료로 음악을 다운로드
# 	12 	포토 부스
# 	12 	Qello
# 	12 	MPost
# 	12 	World Newspapers
# 	12 	투명스크린
# 	12 	1Weather
# 	12 	음악 무료 다운로드
# 	12 	All In One
# 	12 	재미있는 배경
# 	12 	FlashLight
# 	12 	네이버 카페  - Naver Cafe
# 	12 	음악 다운로드
# 	12 	Bing
# 	12 	TripAdvisor
# 	12 	mixi
# 	12 	고구마알람
# 	12 	스파이 카메라
# 	12 	아임IN
# 	12 	한게임 체인지팡팡
# 	12 	프리티 펫 살롱
# 	12 	vouchercloud
# 	12 	통화 차단
# 	12 	Skype
# 	12 	The Weather Channel
# 	12 	Stopwatch
# 	12 	위키백과 모바일
# 	12 	Menstrual Calendar
# 	12 	Twitvid
# 	12 	支付宝
# 	12 	Zipcar
# 	12 	Evernote Food
# ####################################################################################################
# 	13 	What's the Movie?
# 	13 	BMX 묘기
# 	13 	Safeway
# 	13 	날씨 - 5일
# 	13 	저격병
# 	13 	Bible
# 	13 	Plan B
# 	13 	유리에 비
# 	13 	CGV
# 	13 	내 계산기
# 	13 	이게 뭐야?
# 	13 	미소! 재미 :)
# 	13 	CANAL+
# 	13 	우주전
# 	13 	성격 테스트
# 	13 	공포의 집
# 	13 	다이 하드
# 	13 	Al Ahram
# 	13 	Pizza Hut
# 	13 	비행 컨트롤
# 	13 	스타 걸
# 	13 	모험가
# 	13 	Banque
# 	13 	패션 아이콘
# 	13 	Bible Study
# 	13 	고양이 소리
# 	13 	Quit Smoking
# 	13 	홈플러스
# 	13 	만화를 그리는 방법
# 	13 	The Weather Network
# 	13 	불꽃놀이
# 	13 	The Legend of Sleepy Hollow
# 	13 	The Economist
# 	13 	농구 슛
# 	13 	숨은 낱말 찾기
# 	13 	Love Academy
# 	13 	루팡
# 	13 	GO Book
# 	13 	Play Tennis
# 	13 	원숭이 소리를
# 	13 	조조할인
# 	13 	심리 테스트
# 	13 	Global Defense
# 	13 	박가네
# 	13 	비밀이 숨겨진
# 	13 	구름
# 	13 	British Gas
# 	13 	Radio ZET
# 	13 	K
# 	13 	동물 소리
# 	13 	자연 액자
# 	13 	Plumber
# 	13 	Millionaire
# 	13 	솔리테르
# 	13 	지금 날씨
# 	13 	le Parisien
# 	13 	Wimbledon
# 	13 	내 기분
# 	13 	이상한 모험
# 	13 	우리마트
# 	13 	러시안 룰렛
# 	13 	버거
# 	13 	Who wants to be a millionaire?
# 	13 	벽 다리
# 	13 	버즐 피버 for Kakao
# 	13 	레스토랑스타
# 	13 	해적 (Pirates)
# 	13 	농구 올스타
# 	13 	보석 Jewels
# 	13 	Knock Down
# 	13 	드럼
# 	13 	조커
# 	13 	다람쥐.
# 	13 	그린팜
# 	13 	참고 사항
# 	13 	숲을 지켜라
# 	13 	폭풍
# 	13 	생일
# 	13 	Campus Life
# 	13 	Love Test!
# 	13 	기억
# 	13 	고양이 소리를
# 	13 	Good Morning
# 	13 	숨은 그림 찾기
# 	13 	상자
# 	13 	소환전쟁
# 	13 	KickBack
# 	13 	배고픈 물고기
# 	13 	영웅삼국지
# 	13 	Tagesschau
# ####################################################################################################
# 	14 	Yahoo! Mail
# 	14 	Nova Launcher Prime
# 	14 	SD Speed Increase
# 	14 	실시간 번역 - TouchTalk
# 	14 	Qik Video
# 	14 	Virtual Table Tennis 3D
# 	14 	Tub Thumper
# 	14 	배터리 표시기
# 	14 	WorldMate
# 	14 	Time Mobile
# 	14 	배경화면 HD
# 	14 	미래에셋증권 M-Stock
# 	14 	Hungry Shark
# 	14 	LogMeIn Ignition
# 	14 	GO Weather
# 	14 	Real Racing 2
# 	14 	Vignette Demo
# 	14 	Adobe Reader
# 	14 	Scientific Calculator
# 	14 	네이버 메일 - Naver Mail
# 	14 	Fruit Ninja
# 	14 	MiniSquadron!
# 	14 	PhotoFunia
# 	14 	Sliding Puzzles
# 	14 	AirAttack HD
# 	14 	키움증권 영웅문S
# 	14 	Apex Launcher Pro
# 	14 	AutoCAD WS
# 	14 	Cut the Rope
# 	14 	Unblock Me FREE
# 	14 	수스 번역
# 	14 	Pho.to Lab
# 	14 	Digital Clock
# 	14 	Raging Thunder
# 	14 	Tip Calculator
# 	14 	Car Mode
# 	14 	Zebra Paint
# 	14 	Wondershare PowerCam
# 	14 	Chess Free
# 	14 	라인 카메라 LINE camera
# 	14 	1Mobile Market
# 	14 	Traffic Rush
# 	14 	Tap Tap Revenge 4
# 	14 	Splashtop 2 - Remote Desktop
# 	14 	TuneIn Radio Pro
# 	14 	Mobile Metronome
# 	14 	카카오톡 KakaoTalk
# 	14 	Sleep Timer
# 	14 	Winamp
# 	14 	SnapTell
# 	14 	Trapster
# 	14 	Virtual Zippo® Lighter
# 	14 	Dropbox
# 	14 	Business Calendar
# 	14 	맥스홈 런처
# 	14 	내 손안의 미니 전광판
# 	14 	AppRemover
# 	14 	TalkBack
# 	14 	Layar
# 	14 	통화 플래시
# 	14 	Smart Alarm Clock
# 	14 	Paper Camera
# 	14 	Mint.com Personal Finance
# 	14 	말하는 개, 벤
# 	14 	Drums HD
# 	14 	배터리 HD
# 	14 	커플 필수 앱, 비트윈 - Between
# 	14 	SilentCam
# 	14 	배터리 인디케이터
# 	14 	SugarSync
# 	14 	브레인 웨이브 튜너
# 	14 	스마트폰 계급도 (랭킹)
# 	14 	GPS Test
# 	14 	PCM Recorder
# 	14 	Real Racing
# 	14 	Photo Editor
# 	14 	Doodle Jump
# 	14 	Currency Converter
# 	14 	Retro Camera
# 	14 	roidizer
# 	14 	합성의 달인 2(카카오스토리 얼굴 합성 사진 을올리자)
# 	14 	GPS Tracker
# 	14 	틱톡 - TicToc
# 	14 	간단한 MP3 다운로더
# 	14 	Pixlr-o-matic
# 	14 	RMaps
# 	14 	SkyDrive
# 	14 	뭐야이번호
# 	14 	Advanced Mobile Care
# 	14 	Screen Filter
# 	14 	Vlingo
# 	14 	How to Tie a Tie
# 	14 	터치 캘린더
# 	14 	Brightness Level
# 	14 	볼륨 조절
# 	14 	Reckless Racing
# 	14 	Discount Calculator
# 	14 	Canon Easy-PhotoPrint
# 	14 	Yahoo! Messenger
# 	14 	바이로봇 모바일
# 	14 	슬라임 대 버섯(Slime vs. Mushroom)
# 	14 	Bejeweled® 2
# 	14 	Remember The Milk
# 	14 	신한카드 - Smart 신한
# 	14 	Opera 브라우저
# 	14 	Raziko
# 	14 	Houzz Interior Design Ideas
# 	14 	내 폰안에 114
# 	14 	Birzzle
# 	14 	기념일 관리
# 	14 	Sticky Note
# 	14 	Shazam Encore
# 	14 	Skitch
# 	14 	Speedtest
# 	14 	Cloud Print
# 	14 	Pic Collage
# 	14 	Snapseed
# 	14 	와이파이 파일 탐색기
# 	14 	MOTOACTV
# 	14 	OK캐쉬백 터치
# 	14 	FBReader
# ####################################################################################################
# 	15 	제노니아5
# 	15 	갓워즈 : 신들의 전쟁
# 	15 	캐시팡
# 	15 	몬스터워로드
# 	15 	드래곤빌리지
# 	15 	Music Download
# 	15 	Blogger-droid
# 	15 	갱스터 베가스
# 	15 	메이플스토리Live
# 	15 	카툰워즈블레이드
# 	15 	바운스볼
# 	15 	무슨캐시받지?
# 	15 	Music download
# 	15 	쿠키런 크리스탈 생성기
# 	15 	넥슨 올스타즈
# 	15 	컴투스프로야구2013
# 	15 	크로이센2+
# 	15 	Daily Horoscope
# 	15 	마구마구2012
# 	15 	카툰워즈2
# 	15 	Growtopia
# 	15 	100 Doors
# ####################################################################################################
# 	16 	필수어플가이드
# 	16 	일본어 섹시 동영상
# 	16 	Smart Tools - 도구상자
# 	16 	문자 추적기
# 	16 	Flipboard: 여러분의 소셜 뉴스 매거진
# 	16 	짠돌이 가계부
# 	16 	V3 Mobile Plus 2.0
# 	16 	지하철 도착정보
# 	16 	음성검색
# 	16 	문서화 시스템 ADWTheme
# 	16 	네이버 북스–15만권의 전자책-Naver Books
# 	16 	오토보이 블랙박스
# 	16 	StudyMaster 스터디마스터
# 	16 	콜센터전화번호부
# 	16 	YTN for Phone
# 	16 	한방에 메모장
# 	16 	MyMusicOn 가사지원 음악 플레이어
# 	16 	원기날씨
# 	16 	음성검색​
# 	16 	도서관 좌석 정보
# 	16 	지하철 종결자 : Smarter Subway
# 	16 	LIVE스코어
# 	16 	MBC 라디오 mini
# 	16 	xPiano
# 	16 	배달통 시즌2 - 모바일 결제, OK캐쉬백 적립/사용
# 	16 	급수별한자학습
# 	16 	지하철 내비게이션
# 	16 	퀴즈 무한도전 - Qube 퀴즈큐브
# 	16 	필수추천 무료어플 77
# 	16 	Vitamio Plugin ARMv7+NEON
# 	16 	열린약국찾기
# 	16 	Google 번역
# 	16 	iReader
# 	16 	모두의 웹툰
# ####################################################################################################
# 	17 	킹스엠파이어
# 	17 	Auto Trader
# 	17 	TransPot
# 	17 	آيات:القرآن الكريم Holy Quran
# 	17 	Photo Sketch
# 	17 	마이레스토랑
# 	17 	MP3 다운로드
# 	17 	Snipe
# 	17 	Computer
# 	17 	Chess Online
# 	17 	농장 스토리™
# 	17 	FML
# 	17 	Breaking News!
# 	17 	Flickr
# 	17 	IM+
# 	17 	Weatherzone
# 	17 	Voyages-SNCF
# 	17 	Data Monitor
# 	17 	Jobs
# 	17 	DIRECTV
# 	17 	슈퍼펭귄 for Kakao
# 	17 	CommBank
# 	17 	World Series of Poker
# 	17 	X-레이 스캐너
# 	17 	thetrainline
# 	17 	재팬 라이프
# 	17 	RF온라인
# 	17 	Hotel Story
# 	17 	비씨카드(BC카드,BCcard)
# 	17 	Catan
# 	17 	Hangman
# 	17 	한붓그리기
# 	17 	전기 터치
# 	17 	Bubble
# 	17 	Currency
# 	17 	Chess Game
# 	17 	Bump
# 	17 	ABCs
# 	17 	Crime Story
# 	17 	나이트 비전 카메라
# 	17 	Avatar
# 	17 	Horoscopes
# 	17 	Starbucks
# 	17 	Color Match
# 	17 	Do it (Tomorrow)
# 	17 	Commando
# ####################################################################################################
# 	18 	동굴 탐험가
# 	18 	탁구
# 	18 	Hamlet (햄릿)
# 	18 	미로
# 	18 	초음속 ™
# 	18 	폭발물 전문가
# 	18 	톱 모델
# 	18 	거짓말 탐지기
# 	18 	동화
# 	18 	웃는 아빠
# 	18 	일렉트릭 기타
# 	18 	축구 (Soccer)
# 	18 	답은 무엇입니까?
# 	18 	동전 뒤집기
# 	18 	tvyo
# 	18 	축구선수
# 	18 	1km
# 	18 	배관공
# 	18 	날려버리다
# 	18 	더러운 소리
# 	18 	차이를 발견
# 	18 	일화.
# 	18 	테니스
# 	18 	성경의 구절
# 	18 	S.W.A.T Sniper
# 	18 	지구
# 	18 	Sniper 저격병
# 	18 	튀다
# 	18 	Yala
# 	18 	배구
# 	18 	날 먹여
# 	18 	성경
# 	18 	마인드 게임
# 	18 	Coloring Book (칠하기 그림책)
# 	18 	로빈슨
# 	18 	미로!
# 	18 	거울
# 	18 	지도
# 	18 	축구 페널티
# 	18 	무서운 집
# 	18 	전쟁의 시대
# 	18 	궁술
# 	18 	빙고 카지노 ™
# 	18 	반딧불
# 	18 	연합뉴스
# 	18 	용의 제국
# 	18 	조각 그림 맞추기
# 	18 	동물의 소리
# 	18 	동양시
# 	18 	양궁
# 	18 	주차 트럭
# 	18 	원시인이
# 	18 	piqUp
# 	18 	절대음감
# 	18 	IQ 테스트
# 	18 	뱀 소리
# 	18 	친구만들기
# 	18 	친필
# 	18 	담배 라이터
# 	18 	채찍 소리
# 	18 	생쥐 (Mouse)
# 	18 	모터사이클
# 	18 	경찰 등
# 	18 	스피드건 - Speed Gun
# ####################################################################################################
# 	19 	다음 tv팟 - Daum tvPot
# 	19 	Megapolis
# 	19 	飞信
# 	19 	Cordy
# 	19 	말달리자 for Kakao
# 	19 	Flood-It!
# 	19 	Last_Defender
# 	19 	Hamster Life
# 	19 	Blogger
# 	19 	좀비거너
# 	19 	꾸쥬워마이걸
# 	19 	LINE PLAY
# 	19 	Magic 8 Ball
# 	19 	이사만루2013 KBO
# 	19 	Assaulter
# 	19 	MapQuest
# 	19 	미니게임천국(MiniGame Paradise)
# 	19 	크리스마스는 어디에?
# 	19 	Pano
# 	19 	바이킹아일랜드 for Kakao
# 	19 	uBank
# 	19 	Myspace
# 	19 	Wired (유선)
# 	19 	Panic Flight
# 	19 	프로야구 for Kakao
# 	19 	Emoticons
# 	19 	Life is Crime
# 	19 	100 Pushups
# 	19 	4Sale
# 	19 	QQ空间
# 	19 	바둑 for Kakao
# 	19 	Miracle City
# 	19 	Wipeout
# 	19 	MetaTrader 4
# 	19 	iStoryBooks
# 	19 	Dead Space™
# 	19 	블록군
# 	19 	SpeedCar
# 	19 	The Verge
# 	19 	슈퍼주니어 셰이크
# 	19 	adidas miCoach
# 	19 	Locus Pro
# 	19 	슬롯 슬롯™
# 	19 	OnLive
# 	19 	Carrom
# 	19 	WordPress
# 	19 	NOOK
# 	19 	Solar Charger
# 	19 	LiveScore
# 	19 	Dream League Soccer
# 	19 	AliExpress
# 	19 	Vector
# 	19 	스틸커맨더스
# 	19 	Monster Shooter
# 	19 	가속스캔들 for Kakao
# ####################################################################################################
# 	20 	FINAL FANTASY AIRBORNE BRIGADE
# 	20 	아쿠의 퍼즐패밀리 for Kakao
# 	20 	이터니티워리어스2
# 	20 	AppGratis
# 	20 	TSF Shell
# 	20 	Moto X Mayhem
# 	20 	Super Dynamite Fishing
# 	20 	Reckless Getaway
# 	20 	제노니아3
# 	20 	Aquarium Live Wallpaper
# 	20 	Can Knockdown 2
# 	20 	Real Racing 3
# 	20 	Holo Launcher
# 	20 	PocketInvEditor
# 	20 	Network Monitor
# 	20 	XFINITY TV
# 	20 	TETRIS® free
# 	20 	Age of Zombies
# 	20 	Youda Survivor
# 	20 	Farm Invasion USA
# 	20 	SHADOWGUN: DeadZone
# 	20 	No Lock
# 	20 	Socialcam
# 	20 	Freecell
# 	20 	건브로스2
# 	20 	Trial Xtreme 2 Winter
# 	20 	모던 컴뱃 4: 제로 아워
# 	20 	컨트랙트 킬러: 좀비
# 	20 	screenshot
# 	20 	Running Fred
# 	20 	캐슬디펜스
# 	20 	Super Stickman Golf
# 	20 	Share Apps
# 	20 	Screenshot It
# 	20 	좀비드라이브
# 	20 	Tank Riders
# 	20 	Cartoon Camera
# 	20 	Majesty: Fantasy Kingdom Sim
# 	20 	Fieldrunners 2
# 	20 	Juggernaut Revenge of Sovering
# 	20 	Wallpaper Changer
# 	20 	BATTLE BEARS -1
# 	20 	Great Big War Game
# 	20 	Slingshot Racing
# 	20 	Xbox SmartGlass
# 	20 	Reckless Racing 2
# 	20 	Zombies Live™
# 	20 	Diamond Dash
# 	20 	Photo Tools
# 	20 	스왐피(Swampy) Where Is My Water?
# 	20 	Shark Dash
# 	20 	Spotify
# 	20 	Buddy Rush
# 	20 	건 브로스
# 	20 	Words With Friends Free
# 	20 	Google Offers
# 	20 	스크린샷 UX
# 	20 	Tiny Troopers
# 	20 	Download All Files
# 	20 	Pandora® internet radio
# 	20 	Rdio
# 	20 	Little Photo
# 	20 	Camera Effects
# 	20 	Grabatron
# 	20 	Ruzzle
# 	20 	Angry Birds Space Premium
# 	20 	Grand Prix Story
# 	20 	FTPServer
# 	20 	Angry Birds Friends
# 	20 	Glow Hockey 2
# 	20 	LINE Card
# 	20 	POGO Games
# 	20 	Talking Larry the Bird
# 	20 	글로리 스카이 for Kakao
# 	20 	고스트 스나이퍼 : 좀비
# 	20 	Hulu Plus
# 	20 	Bejeweled Blitz
# 	20 	KungFu Warrior
# 	20 	Ultimate Guitar Tabs
# 	20 	InstaWeather
# 	20 	버블킹 for Kakao
# 	20 	9이닝스: 2013프로야구
# 	20 	Burn the Rope
# 	20 	네모네모 피크로스
# 	20 	Puzzle Quest 2
# 	20 	iPhone Lock Screen
# 	20 	Unrar
# 	20 	지퍼7
# 	20 	사무라이 vs 좀비
# 	20 	Where's My Perry?
# 	20 	제노니아4
# 	20 	Tiny Monsters
# 	20 	MASS EFFECT™ INFILTRATOR
# 	20 	Jelly Defense
# 	20 	Russian Keyboard
# 	20 	GO Contacts EX
# 	20 	Temple Run: Brave
# 	20 	FrostWire
# 	20 	Fruit Ninja Free
# 	20 	Babel Rising 3D!
# 	20 	Donkey Jump
# 	20 	NFL Kicker 13
# 	20 	Toy Defense
# 	20 	Zombie HQ
# 	20 	Virtua Tennis™ Challenge
# 	20 	Vonage Mobile®
# 	20 	King's Bounty: Legions
# 	20 	다함께 고고고 for Kakao
# 	20 	Myxer
# 	20 	X-Plane 9
# 	20 	Bad Piggies
# 	20 	Angry Birds Star Wars
# 	20 	Slacker Radio
# 	20 	Wave Launcher
# 	20 	Gentle Alarm
# 	20 	Plumber Crack
# 	20 	Kingdom Rush
# 	20 	Ninja Rush
# 	20 	Chicken Invaders 3
# 	20 	Parking3d
# 	20 	Greedy Spiders
# 	20 	Lane Splitter
# 	20 	Draw Something by OMGPOP
# 	20 	Scramble With Friends
# 	20 	Battery Monitor Widget
# 	20 	Online Radio
# 	20 	이터니티 워리어스
# 	20 	Angry Birds Space
# 	20 	Smash Cops Heat
# 	20 	Tip-Off Basketball
# 	20 	한큐 for Kakao
# 	20 	SketchBook Mobile Express
# 	20 	Dark Summoner
# 	20 	WiFi Tethering
# 	20 	Robotek
# 	20 	Square Register
# 	20 	Google Search
# 	20 	써몬히어로
# 	20 	Text Edit
# 	20 	Minecraft - Pocket Edition
# 	20 	Extreme Formula
# 	20 	운명의 클랜배틀
# 	20 	Network Speed
# 	20 	Army of Darkness Defense
# 	20 	DevilDark: The Fallen Kingdom
# 	20 	Gem Miner
# 	20 	Angry Birds Rio
# 	20 	GoToMeeting
# 	20 	Temple Run: 오즈
# 	20 	Flick Golf Extreme
# 	20 	Tekken Card Tournament
# 	20 	아니마 - Anima by Hangame
# 	20 	LINE Tools
# 	20 	Ski Safari
# 	20 	Earn to Die
# 	20 	Extreme Skater
# 	20 	Respawnables
# 	20 	Towers N' Trolls
# 	20 	Pig Rush
# 	20 	Hungry Shark Evolution
# 	20 	My Verizon
# 	20 	Angry Piggy
# 	22 	Safe Neighborhood
# 	22 	Revolver
# 	22 	Rainy Days
# 	22 	Predators™
# 	22 	Russian Roulette
# 	22 	Lose It!
# 	22 	WWE
# 	22 	Yumm
# 	22 	Radiant
# 	22 	Top Stylist
# 	22 	Curiosity
# 	22 	The CATch!
# 	22 	Take me Home
# 	22 	The Washington Post
# 	22 	The Lone Ranger
# 	22 	Sit Ups
# 	22 	Solo
# 	22 	Final Countdown
# 	22 	Speed Skater
# 	22 	로스트 아일랜드
# 	22 	ESPN Radio
# 	22 	Captain America
# 	22 	Ice Cream Maker
# 	22 	The Whip
# 	22 	Push Ups
# 	22 	My Prayer - صلاتي
# 	22 	Banjo
# 	22 	Concur
# 	22 	Pirates of the Caribbean
# 	22 	Grow
# 	22 	Medscape
# 	22 	Sanity
# 	22 	Valor
# 	22 	Babysitting
# 	22 	Allegro
# 	22 	whisper
# 	22 	Grenadier
# 	22 	Thousand+
# 	22 	Piano
# 	22 	Hit It!
# 	22 	WHERE
# 	22 	바보 테스트
# 	22 	Cut It!
# 	22 	United States Constitution
# 	22 	Warship
# 	22 	BMX Rider
# 	22 	Scopa
# 	22 	Death Battle
# 	22 	Street Football
# 	22 	Wreck-it Ralph
# 	22 	Hearts!
# 	22 	INDESTRUCTIBLE
# 	22 	Cover Girl
# 	22 	Elite Force
# 	22 	폭행몬스터
# 	22 	My Clinic
# 	22 	Swamp People
# 	22 	Guns
# 	22 	Nail Salon
# 	22 	Heart Breaker
# 	22 	AlloCine
# 	22 	Riddle That
# 	22 	20 minutes.fr
# 	22 	ZDFmediathek
# 	22 	스프레이 무료
# 	22 	The Key
# 	22 	Toucher
# 	22 	NBC News
# 	22 	Adele
# 	22 	공튕기기
# 	22 	The Streetz
# 	22 	Balance BY
# 	22 	패밀리팜
# 	22 	My Guitar
# 	22 	KKBOX
# 	22 	GETTINGS
# 	22 	Moon 3D
# 	22 	무덤 탈출
# 	22 	Quell
# 	22 	UNO™
# 	22 	タロット占い
# 	22 	에어 윙
# 	22 	Pair Up
# 	22 	드래곤 볼 Z
# 	22 	Sporos
# 	22 	Quran - القرآن الكريم
# 	22 	Pancakes!!!
# 	22 	Find Something
# 	22 	My Piano
# 	22 	Sector Strike
# 	22 	Dwell
# 	22 	Dentist Office
# ####################################################################################################
# 	23 	몬스터 연맹
# 	23 	Farming Simulator
# 	23 	삼국지천하제패W+
# 	23 	ETERNITY WARRIORS 2
# 	23 	퀸스크라운2
# 	23 	Into the Dead
# 	23 	Call of Mini: Sniper
# 	23 	Football Manager Handheld 2013
# 	23 	Legend of the Cryptids
# 	23 	팔라독 mini for Kakao
# 	23 	Beat the Boss
# 	23 	The Tribez
# 	23 	아야카시 음양록
# 	23 	펀치히어로
# 	23 	SoundTracking
# 	23 	카드캡쳐삼국지
# 	23 	영웅의 품격 for Kakao
# 	23 	Puzzle Attack
# 	23 	BUG VILLAGE
# 	23 	Sudoku
# 	23 	GO Backup
# 	23 	Call of Mini: Zombies
# 	23 	iMobsters™
# 	23 	Block Story
# 	23 	나이틀리 어드벤처 for Kakao
# 	23 	Empire Story™
# 	23 	Minebuilder
# 	23 	ALL NEW 방탈출
# 	23 	ZombieSmash
# 	23 	The Simpsons™: Tapped Out
# 	23 	The Sandbox
# 	23 	Star Legends
# 	23 	리얼사커 2012
# 	23 	Survivalcraft
# 	23 	Zombieville USA
# 	23 	Foodspotting
# 	23 	Halo Reach
# 	23 	카트라이더 러쉬+ 2.0
# 	23 	Rule The Kingdom
# 	23 	Subway Surfers
# 	23 	템페스트 사가
# 	23 	Riptide GP2
# 	23 	사무라이 vs 좀비 2
# 	23 	Undead Slayer
# 	23 	NBA 2K13
# 	23 	DragonVale
# 	23 	TextNow
# 	23 	Catapult King
# 	23 	Amazon MP3
# 	23 	던전 헌터 4
# 	23 	던전 헌터 3
# 	23 	Nimble Quest
# 	23 	Surviving High School
# 	23 	Call of Duty Black Ops Zombies
# 	23 	Arcane Legends
# 	23 	Devil Ninja
# 	23 	SongPop
# 	23 	토이 빌리지
# 	23 	Vampires Live™
# 	23 	아쿠아스토리
# ####################################################################################################
# 	24 	삼성 모바일 프린트
# 	24 	Third Blade
# 	24 	K-9 Mail
# 	24 	Need for Speed™ Hot Pursuit
# 	24 	TheEndApp
# 	24 	CONTRACT KILLER: ZOMBIES
# 	24 	파워세이버
# 	24 	Doodle God™
# 	24 	스노우보딩 서밋X
# 	24 	Need for Speed™ Most Wanted
# 	24 	벅스 뮤직 – 무제한 음악 듣기
# 	24 	TapDefense
# 	24 	Plants vs. Zombies
# 	24 	Run Like Hell! Heartbreaker
# 	24 	아스팔트 7: 히트
# 	24 	Pattrn
# 	24 	Movies by Flixster
# 	24 	AgingBooth
# 	24 	Slide Puzzle
# 	24 	사상 가장 어려운 게임 2
# 	24 	카카오톡 테마 만들기 - PRO
# 	24 	Death Racing
# 	24 	iRunner
# 	24 	 좀비 런
# 	24 	QQ音乐
# 	24 	U-OTP
# 	24 	Audiobooks
# 	24 	Jet Car Stunts
# 	24 	다함께 퐁퐁퐁 for Kakao
# 	24 	LIL' KINGDOM
# 	24 	Ragdoll Blaster
# 	24 	JunoWallet
# 	24 	Hungry Shark - Part 3
# 	24 	Whacksy Taxi
# 	24 	iSlash
# 	24 	Netflix
# 	24 	Tiki Kart 3D
# 	24 	Easy Downloader
# 	24 	애니팡 사천성 for Kakao
# 	24 	NEED FOR SPEED™ Shift
# 	24 	Backbreaker Football
# 	24 	타이니팜 (Tiny Farm)
# 	24 	CSR Racing
# 	24 	Tasks (할 일)
# 	24 	UNO™ FREE
# 	24 	Fragger
# 	24 	PicsArt - Photo Studio
# 	24 	GT Racing: Motor Academy Free+
# 	24 	3D Pool Master Pro
# 	24 	4shared
# 	24 	Deezer
# 	24 	Rail Maze
# 	24 	Jaws™ Revenge
# 	24 	터치믹스2
# 	24 	Locale
# 	24 	Osmos HD
# 	24 	Draw Something Free
# 	24 	SmartWatch
# 	24 	리버스 (이벤트특가)
# 	24 	Find My Phone
# 	24 	CHAOS RINGS
# 	24 	Mini Pets
# 	24 	Temple Run 2
# 	24 	Facebook Home
# 	24 	Google Wallet
# 	24 	Modern Combat 2: Black Pegasus
# 	24 	Battleheart
# 	24 	HeyTell
# 	24 	Bubble Shoot
# 	24 	Pocket Legends
# 	24 	Last.fm
# 	24 	Video Downloader
# 	24 	JAZZ: Trump's Journey
# 	24 	Kik Messenger
# 	24 	Freecell Solitaire
# 	24 	Pocket Frogs
# 	24 	FreeCell Solitaire
# 	24 	Supermarket Mania® 2
# 	24 	Samurai II: Vengeance
# 	24 	젤리뽀 for Kakao
# 	24 	STARDOM: THE A-LIST
# 	24 	body symbol
# 	24 	Can Knockdown
# 	24 	Agent Dash
# 	24 	Bubble Blast
# 	24 	FastBall 2
# 	24 	MEGASTUNT™ Mayhem
# 	24 	히어로즈워 for Kakao
# 	24 	Gameloft LIVE!
# 	24 	Songza
# 	24 	LockBot Free
# 	24 	Pocket League Story
# 	24 	컴투스프로야구2011
# 	24 	TinyLegends - Crazy Knight
# 	24 	Trial Xtreme
# 	24 	Beauty Camera
# 	24 	Falling Fred
# 	24 	푸딩카메라 - Pudding Camera
# 	24 	플랜츠워
# 	24 	Shake Spears!
# 	24 	Emross War
# 	24 	TVCatchup
# 	24 	날아라 팬더 비행단 for Kakao
# 	24 	Angry Birds Seasons
# 	24 	Judge Dredd vs. Zombies
# 	24 	터치터치홀인원 for Kakao
# 	24 	Telnet
# 	24 	Prize Claw
# 	24 	에어펭귄프렌즈 for Kakao
# 	24 	윈드러너 for Kakao
# 	24 	배경화면
# 	24 	Sentinel 3: Homeworld
# 	24 	금속탐지기 - Metal Detector
# 	24 	HTR High Tech Racing
# 	24 	Stair Dismount
# 	24 	Mini Motor Racing
# 	24 	Crazy Snowboard
# 	24 	Destiny Defense:Angel or Devil
# 	24 	Plants vs. Zombies™
# 	24 	Bad Piggies HD
# 	24 	Millionaire City
# 	24 	Jetpack Joyride
# 	24 	미디블 캐슬 디펜스
# 	24 	Trillian
# 	24 	배틀 오브 레전드 (바하무트)
# 	24 	A Online Radio
# 	24 	데빌메이커: 도쿄 for Kakao
# 	24 	유리 돋보기
# 	24 	Angry Birds
# 	24 	SFCave
# 	24 	Triple Town
# 	24 	They Need To Be Fed
# 	24 	DocumentsToGo Full Version Key
# 	24 	캔디팡 for Kakao
# 	24 	BeyondPod Podcast  Manager
# 	24 	The Sims™ 3
# 	24 	Lost Phone
# 	24 	Sleep Time - Alarm Clock
# 	24 	Sky Burger
# 	24 	NinJump
# 	24 	Angry Birds Star Wars HD
# 	24 	Tank Hero
# 	24 	우파루마운틴 for Kakao
# 	24 	ClockSync
# 	24 	Nun Attack
# 	24 	Cows Vs Aliens
# 	24 	아스팔트 8: 에어본
# 	24 	Car Home
# 	24 	Wind-up Knight
# 	24 	사진꾸미기
# 	24 	볼링 3D
# 	24 	삼국지 디펜스 2
# 	24 	오더앤카오스 온라인
# 	24 	Snapchat
# 	24 	Google Finance
# 	24 	Smurfs' Village
# 	24 	Flick Soccer!
# 	24 	Spirit HD
# 	24 	홈런배틀 3D (Homerun Battle 3D)
# 	24 	도돌 런처 - dodol Launcher - 폰꾸미기
# 	24 	Art Of Glow
# 	24 	mSecure - Password Manager
# 	24 	Mystery of the Crystal Portal
# 	24 	Princess Punt
# 	24 	NBA: King of the Court
# 	24 	Cleopatra's Pyramid
# 	24 	Great Little War Game
# 	24 	Bubble level
# 	24 	Yandex.Maps
# 	24 	Pool Break Pro
# 	24 	Temple Run
# 	24 	DEAD TRIGGER
# 	24 	사진 꾸미기
# 	24 	Urban Rivals

# %%
nClusters = 20

kms = KMeans(n_clusters=nClusters)
kms.fit(dftemphead2)

print kms.cluster_centers_
print kms.labels_[:nClusters]

plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.
# Out:
# [[-0.82009733 -0.96961092 -0.88509031 ..., -0.6938349  -1.09836838
#   -0.90468734]
#  [ 0.15923974  0.01546641 -0.08282623 ..., -0.18397408  0.73952953
#    0.11198766]
#  [-1.03681765 -0.63251091 -0.78682149 ...,  1.09909845 -1.0194947
#   -0.21241214]
#  ...,
#  [ 0.49210823 -0.23081207  0.26377579 ..., -0.37932829  2.30254947
#   -1.13009719]
#  [-1.05337105  0.28317203 -0.40757259 ..., -0.78842457 -0.53822703
#    0.65128351]
#  [-0.19189239  0.21636877 -0.29348499 ...,  0.54575354  0.20843173
#    0.64800111]]
# [ 0  1  1  9  9  9  3 13  1 19 16  1  6 19 18 14 16  8  3 18]

# %%
nClusters = 30

kms = KMeans(n_clusters=nClusters)
kms.fit(dftemphead2)

print kms.cluster_centers_
print kms.labels_[:nClusters]

plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.
# Out:
# [[  5.88102703e-01   3.23664772e-01   1.00498014e+00 ...,  -1.48834654e-01
#    -5.97910320e-01  -3.38824355e-01]
#  [ -2.87500837e-01  -8.31672045e-01  -3.20631953e-01 ...,   6.28543956e-01
#    -3.44808826e-01  -4.20279968e-01]
#  [ -2.03538942e-04  -1.88508766e-01  -1.98210792e-02 ...,  -7.14926154e-01
#     2.39010535e-01  -1.98941414e-01]
#  ...,
#  [  8.57717222e-01   4.63352122e-01   5.22877524e-01 ...,   3.99471598e-01
#     1.68213608e+00   8.77603907e-01]
#  [  1.64976500e-01  -1.35571786e-01   1.54611191e-02 ...,   1.80243553e-01
#     9.17575031e-01   1.84210762e-01]
#  [ -4.36478028e-01   6.84110559e-01  -4.57885813e-01 ...,  -1.52910737e-01
#     1.40771686e-01   9.90444944e-01]]
# [24  5 28 24 24 24  0  6  2 27 12  5 14 26 26  9 12 11  0 26  4 22 13 25 27
#   4 10 25 14 23]
