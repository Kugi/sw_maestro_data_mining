# %%
import pgdb
import pandas
import pickle
from pandas import DataFrame, Series

# %% [markdown]
# 데이터베이스에서 유효하다고 보이는 앱들의 PMI 값을 가져온다.<br>
# 앱 이름(app_name)에 ampersand(&)나 sharp(#)가 포함되어 있으면 부적절한 결과가 나오는 것으로 보인다.

# %%
#db = pgdb.connect(database="application",host="soma3.buzzni.com:5432",user="soma",password="maestro@)!#")
#entity_pmi_table = pandas.io.sql.read_frame('select * from app_keyword_pmi',db)

db = pgdb.connect(database="application",host="soma3.buzzni.com:5432",user="soma",password="maestro@)!#")
#entity_pmi_table = pandas.io.sql.read_frame("select * from app_keyword_pmi where pmi != 0 order by pmi desc", db)
entity_pmi_table = pandas.io.sql.read_frame("select * from app_keyword_pmi where pmi != 0 and app_name not like '%&%' and app_name not like '%#%' order by pmi desc", db)
#entity_pmi_table = pickle.load(file('./entity_pmi_table.df'))

# %%
entity_pmi_table.to_pickle("entity_pmi_table_final.df")
entity_pmi_table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 358153 entries, 0 to 358152
# Data columns (total 4 columns):
# app_name       358153  non-null values
# keyword        358153  non-null values
# pmi            358153  non-null values
# update_date    358153  non-null values
# dtypes: float64(1), object(3)

# %%
entity_pmi_table.head()
# Out:
#                     app_name keyword      pmi update_date
# 0              "Daily Perks"   "타이쿤"  10.3148  2013-10-19
# 1               "렙업만이살길 _게임"   "타이쿤"  10.3148  2013-10-19
# 2                "프리티 펫 타이쿤"   "타이쿤"  10.3148  2013-10-19
# 3      "Memoires: The Diary"   "타이쿤"  10.3148  2013-10-19
# 4  "Commando - Final Battle"   "타이쿤"  10.3148  2013-10-19

# %% [markdown]
# 데이터베이스에서 얻어온 유효한 데이터들의 앱 갯수는 다음과 같다.

# %%
names = []
namescnt = {}

for idx, value in entity_pmi_table.iterrows():

    tempstr = value['app_name']
    tempstr = tempstr.replace('"', "")
    if namescnt.has_key(tempstr):
        namescnt[tempstr] += 1
    else:
        namescnt[tempstr] = 0
    try:
        names.remove(tempstr)
    except:
        pass
    names.append(tempstr)
    #if zz >= 50:
    #    break;
        
#print '\n'.join(names)
len(names)
# Out:
# 6470

# %% [markdown]
# 50개 이상의 키워드에 대한 PMI 값이 존재하는 앱만을 뽑아낸다.

# %%
valuableApps = []
for k, v in namescnt.iteritems():
    if v > 50:
        valuableApps.append(k)

len(valuableApps)
# Out:
# 2766

# %% [markdown]
# 전체 키워드를 불러온다.

# %%
def load(fname):
    ''' load the file using std open'''
    f = open(fname,'r')

    data = []
    for line in f.readlines():
        #print line
        data.extend(line.replace('\n','').replace('﻿', '').split(', '))
    
    f.close()

    return data

keyword = load('../utils/data/Keyword.txt')
print " ".join(keyword)
# Out:
# 퍼즐 캐주얼 아케이드 여성 남성 친구 연애 연예 얼굴 속도 돈 랜덤 random 음식 방법 안드로이드 아이폰 android iphone 오락 심리 부자 영어 토익 공부 일정 달력 계획 공략 레이싱 RPG 카드 디펜스 두뇌 시뮬 달리기 슈팅 축구 경영 타이쿤 탈출 추리  장기 비행기 사천성 스포츠 농구 낚시 음악 카톡 골프 당구 야구 볼링 삼국지 전쟁 건강 운동 교육 교통 금융 날씨 뉴스 잡지 데코레이션 도구 도서 참고자료 라이브 배경화면 라이브러리 데모 라이프스타일 블로그 만화 미디어 동영상 비즈니스 편집 사진 생산성 소셜 콘텐츠 쇼핑 위젯 자동차 경주 다이어트 달력 생리 캘린더 사주팔자 궁합 체중 사전 컴퓨터 백과사전 급식 학교 초등학교 중학교 고등학교 대학교 Korea 네비게이션 지하철 종결자 내비 가계부 Money 스마트 계산기 은행 검색어 실시간 신문 클래식 애니 낚시 런처 주소록 폰 바이러스 보안 성경 찬송 바이블 백신 웹 스티커 사주 운세 코믹 3D 별자리 tool 웹툰 플레이어 카메라 벨소리 한글 오피스 office 알바 photo 드라이브 파일 갤러리 그룹 바코드 스캐너 소셜커머스 소셜 어른 노래 꾸미기 패션

# %% [markdown]
# 앱 이름을 인덱스로, 키워드를 칼럼으로 하는 데이터프레임을 만든다.<br>
# 테스트를 위해 사용할 갯수를 조절할 수 있다.

# %%
import numpy

#index = ['a', 'b', 'c']
index = valuableApps#[0:200]#[0:200]
dftemp = pandas.DataFrame(columns=keyword, index = index)
dftemp.loc[:,:] = 0
# print dftemp.columns
# dftemp.loc['류현진 배경화면','퍼즐'] = 0.9
dftemp.shape
# Out:
# (2766, 157)

# %% [markdown]
# 0으로 초기화된 데이터프레임에 PMI 값을 채워 넣는다.

# %%
tempstr = ''
#cntsuccess = 0
#cntfail = 0
count = 0
for idx, row in entity_pmi_table.iterrows():
    _pmi = row['pmi']
    _appname = row['app_name'].replace('"', '').replace('﻿', '')
    _keyword = row['keyword'].replace('"', '').replace('﻿', '')
    
    try:
        dftemp.ix[_appname, _keyword] = _pmi
        if idx < 20:
            print idx, _appname, _keyword, _pmi
        #break
        #ntsuccess+=1
        count+=1
        
    except Exception, e:
        #print "fail:: ", ' '.join(e), _keyword, _pmi
        #cntfail+=1
        #break;
        pass
        
    #if ( idx > 100 ):
    #    break;
print 'done', count
print idx
# Out:
# 13 초코초코타이쿤 타이쿤 10.3108858221
# done
#  285236
# 358152

# %%
#dftemp.keys()

# %% [markdown]
# 입력된 데이터를 눈으로 확인하고 싶다면 다음과 같이 한다.

# %%
dftemp[0:10]['노래']
# Out:
#                                        노래
# Yahoo! Mail                    -0.3029168
# News Republic                    1.638655
# FINAL FANTASY DIMENSIONS        0.9201899
# Jota Text Editor                 1.390194
# Roman Empire                     1.305816
# Telefe                           1.350973
# 제노니아5                           -0.560562
# 무한 레이싱                          0.9714832
# FINAL FANTASY AIRBORNE BRIGADE          0
# 아쿠의 퍼즐패밀리 for Kakao                     0

# %%
dftemp.ix['무한 레이싱']['음악']
# Out:
# 2.1646480843632

# %%
dftemp.ix['무한 레이싱']
# Out:
# 퍼즐                 0
# 캐주얼                0
# 아케이드        5.829084
# 여성          2.030965
# 남성          1.701544
# 친구          1.887312
# 연애          2.859262
# 연예                 0
# 얼굴       -0.00520741
# 속도           4.55722
# 돈           1.480758
# 랜덤          5.076401
# random             0
# 음식           1.11996
# 방법          2.182495
# ...
# office            0
# 알바                0
# photo             0
# 드라이브              0
# 파일         2.363577
# 갤러리               0
# 그룹                0
# 바코드               0
# 스캐너               0
# 소셜커머스             0
# 소셜         3.220041
# 어른                0
# 노래        0.9714832
# 꾸미기               0
# 패션         1.450289
# Name: 무한 레이싱, Length: 157, dtype: object

# %%
### i 값을 바꾸면 원하는 앱의 키워드별 PMI를 모두 볼 수 있다. ###
#i = 1
#d = dftemp[i:i+1]
#print d.index
#for key, pmi in zip(d.columns, d.values[0]):
#    print key, pmi

# %%
dftemp.shape
# Out:
# (2766, 157)

# %% [markdown]
# DBSCAN으로 클러스터링을 시도해본다.

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['load', 'e']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
dftemphead = dftemp
dftemphead = StandardScaler().fit_transform(dftemphead)
print 'dftemphead.shape:', dftemphead.shape
# Out:
# dftemphead.shape: (2766, 157)
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.py:278: UserWarning: StandardScaler assumes floating point values as input, got object
#   "got %s" % (estimator, X.dtype))

# %%
##############################################################################
# Compute DBSCAN
dbscan = DBSCAN().fit(dftemphead)
core_samples = dbscan.core_sample_indices_
labels = dbscan.labels_
core_samples
# Out:
# []

# %%
labels
# Out:
# array([-1., -1., -1., ..., -1., -1., -1.])

# %%
from sklearn.externals import joblib
#joblib.dump(dbscan, '../data/my_model01.pkl', compress=9)
#model_clone = joblib.load('my_model.pkl')

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

##############################################################################
# Plot result
import pylab as pl


# Black removed and is used for noise instead.
unique_labels = set(labels)

unique_labels
# Out:
# {-1.0}

# %%
colors = pl.cm.Spectral(numpy.linspace(0, 1, len(unique_labels)))

#pl.xlim(xmin=-4, xmax=4)
#pl.ylim(ymin=-4, ymax=4)

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'
        markersize = 6
    class_members = [index[0] for index in numpy.argwhere(labels == k)]
    cluster_core_samples = [index for index in core_samples
                            if labels[index] == k]
    for index in class_members:
        x = dftemphead[index]
        #x?
        if index in core_samples and k != -1:
            markersize = 14
        else:
            markersize = 6
        pl.plot(x[0], x[1], 'o', markerfacecolor=col,
                markeredgecolor='k', markersize=markersize)

# %% [markdown]
# PCA를 통해 2차원으로 바꾼 후 시도하면 어떨까.

# %% [markdown]
# 아래는 분산도 그래프를 그리는 함수이다.

# %%
from itertools import cycle

def plot_2D(data, target, target_names):
    colors = cycle('rgbcmykw')
    target_ids = range(len(target_names))
    pl.figure()
    for i, c, label in zip(target_ids, colors, target_names):
        pl.scatter(data[target == i, 0], data[target == i, 1],
                   c=c, label=label)
    pl.legend()

# %% [markdown]
# n_components를 달리 하며 보자.

# %%
pca = PCA(n_components=2, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 2)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 808 ms, sys: 0 ns, total: 808 ms
# Wall time: 806 ms

# %%
pca = PCA(n_components=3, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 3)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 768 ms, sys: 0 ns, total: 768 ms
# Wall time: 770 ms

# %%
pca = PCA(n_components=4, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 4)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 668 ms, sys: 0 ns, total: 668 ms
# Wall time: 669 ms

# %% [markdown]
# n_components가 5가 되자 뭔가 분류가 된 것 처럼 보인다.<br>
# 5보다 더 큰 수를 넣었을 때는 점차 의미가 사라지는 것 같다.

# %%
pca = PCA(n_components=5, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 5)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 452 ms, sys: 0 ns, total: 452 ms
# Wall time: 451 ms

# %%
dbscan2.components_
# Out:
# array([[ 0.68517899,  0.75246042, -1.35565078, -1.13044666,  0.00614517],
#        [ 0.69024124,  0.50359184, -1.31068655, -1.39485163, -0.13894193],
#        [ 0.61856678,  0.84110731, -1.17857573, -0.84196763, -0.07557847],
#        ...,
#        [-1.46612216,  1.51937785,  0.36690353,  0.40631551,  0.90647318],
#        [ 1.14774859,  0.79722779,  1.39014107, -0.33167838,  0.39924037],
#        [ 0.15512223, -1.20299314,  0.52909771, -0.12283158, -0.35431432]])

# %%
pca = PCA(n_components=6, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 6)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 388 ms, sys: 0 ns, total: 388 ms
# Wall time: 390 ms

# %%
pca = PCA(n_components=7, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 7)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 380 ms, sys: 0 ns, total: 380 ms
# Wall time: 380 ms

# %%
pca = PCA(n_components=8, whiten=True).fit(dftemphead)
df_pca = pca.transform(dftemphead)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (2766, 8)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 380 ms, sys: 0 ns, total: 380 ms
# Wall time: 383 ms

# %% [markdown]
# 9부터는 아무런 분류도 볼 수 없다.

# %% [markdown]
# 의미를 파악하려면 어떻게 해야 하는지는 잘 모르겠다.<br>
# 이번에는 PMI가 140개 이상의 키워드에 대해 존재하는 앱들만을 클러스터링 해 보자.

# %%
valuableApps140 = []
for k, v in namescnt.iteritems():
    if v > 140:
        valuableApps140.append(k)

print len(valuableApps140)

index = valuableApps140#[0:200]#[0:200]
dftemp2 = pandas.DataFrame(columns=keyword, index=index)
dftemp2.loc[:,:] = 0
print dftemp2.shape


count = 0
for idx, row in entity_pmi_table.iterrows():
    _pmi = row['pmi']
    _appname = row['app_name'].replace('"', '').replace('﻿', '')
    _keyword = row['keyword'].replace('"', '').replace('﻿', '')
    
    try:
        dftemp2.ix[_appname, _keyword] = _pmi
        if idx < 20:
            print idx, _appname, _keyword, _pmi
        count+=1
        
    except Exception, e:
        #print "fail:: ", ' '.join(e), _keyword, _pmi
        pass
        
print 'done', count
# Out:
# 597
# (597, 157)
# done
#  89261

# %%
dftemphead2 = dftemp2
dftemphead2 = StandardScaler().fit_transform(dftemphead2)
print 'dftemphead.shape:', dftemphead.shape

# Compute DBSCAN
dbscan = DBSCAN().fit(dftemphead2)
core_samples = dbscan.core_sample_indices_
labels = dbscan.labels_
core_samples

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

unique_labels = set(labels)

colors = pl.cm.Spectral(numpy.linspace(0, 1, len(unique_labels)))

#pl.xlim(xmin=-4, xmax=4)
#pl.ylim(ymin=-4, ymax=4)

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'
        markersize = 6
    class_members = [index[0] for index in numpy.argwhere(labels == k)]
    cluster_core_samples = [index for index in core_samples
                            if labels[index] == k]
    for index in class_members:
        x = dftemphead2[index]
        #x?
        if index in core_samples and k != -1:
            markersize = 14
        else:
            markersize = 6
        pl.plot(x[0], x[1], 'o', markerfacecolor=col,
                markeredgecolor='k', markersize=markersize)
# Out:
# dftemphead.shape: (2766, 157)

# %%
pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 2)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 164 ms, sys: 0 ns, total: 164 ms
# Wall time: 163 ms

# %%
pca = PCA(n_components=3, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 3)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 152 ms, sys: 0 ns, total: 152 ms
# Wall time: 150 ms

# %%
pca = PCA(n_components=4, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 4)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 104 ms, sys: 0 ns, total: 104 ms
# Wall time: 102 ms

# %%
pca = PCA(n_components=5, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

print df_pca.shape

dbscan2 = DBSCAN()

# %time print dbscan2.fit(df_pca)

plot_2D(df_pca,dbscan2.labels_,range(len(set(dbscan2.labels_))))
# Out:
# (597, 5)
# DBSCAN(algorithm=auto, eps=0.5, leaf_size=30, metric=euclidean, min_samples=5,
#     p=None, random_state=None)
# CPU times: user 84 ms, sys: 0 ns, total: 84 ms
# Wall time: 84.4 ms

# %% [markdown]
# 6부터는 아무런 분류가 되지 않는다.

# %% [markdown]
# 큰 차이는 없는 것 같다.<br>
# 다른 클러스터링 알고리즘을 적용하면 어떨까.<br>
# <br>
# 먼저 K-means 알고리즘을 사용해보자.

# %%
from sklearn.cluster import KMeans

# %%
nClusters = 5

kms = KMeans(n_clusters=nClusters)
kms.fit(dftemphead2)

#print kms.cluster_centers_
#print kms.labels_[:nClusters]

plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.

# %%
nClusters = 10

dftemphead3 = dftemphead;
vApps = valuableApps140

#kms = KMeans(n_clusters=nClusters)
#kms.fit(dftemphead3)

#print kms.cluster_centers_
#print kms.labels_[:nClusters]

#plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead3)
df_pca = pca.transform(dftemphead3)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

# print kms2.cluster_centers_
# print kms2.labels_

# print '\n'.join(valuableApps140)
cluster_result = zip(vApps, kms2.labels_)
# print cluster_result
cluster_dict = {}
for name, c_id in cluster_result:
    if not cluster_dict.has_key(c_id):
        cluster_dict[c_id] = []
    cluster_dict[c_id].append(name)
# print dftemphead2
c_ids = cluster_dict.keys()
c_ids.sort()
for c_id in c_ids:
    print "#"*100
    for name in cluster_dict[c_id]:
        print "\t",c_id,"\t", name
        
plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.
# Out:
# ####################################################################################################
# 	0 	Avenger
# 	0 	Need for Speed™ Most Wanted
# 	0 	Sky+
# 	0 	미로
# 	0 	Plants vs. Zombies
# 	0 	Spades!
# 	0 	Worms
# 	0 	Curiosity
# 	0 	TV.com
# 	0 	Evernote
# 	0 	GS SHOP
# 	0 	성격 테스트
# 	0 	다크 헌터
# 	0 	다이 하드
# 	0 	야후! 날씨
# 	0 	NEED FOR SPEED™ Shift
# 	0 	사진 텍스트
# 	0 	Google 어스
# 	0 	말하는 고양이 톰
# 	0 	Dropbox
# 	0 	Ringtone Maker
# 	0 	Instagram
# 	0 	Comics
# 	0 	Color
# 	0 	컬러 터치
# 	0 	Financial Times
# 	0 	7x7
# 	0 	바운스볼
# 	0 	성경
# 	0 	2011프로야구
# 	0 	설명
# 	0 	Yahoo! JAPAN
# 	0 	다크 나이트 라이즈
# 	0 	Pinterest
# 	0 	Ustream
# 	0 	Yahoo!
# 	0 	카툰워즈
# 	0 	음악 무료 다운로드
# 	0 	All In One
# 	0 	비디오
# 	0 	무료 영화
# 	0 	Draw!
# 	0 	공 튀기기
# 	0 	버거
# 	0 	TripAdvisor
# 	0 	Google Search
# 	0 	Pictorial
# 	0 	나침반
# 	0 	Skitch
# 	0 	TV편성표
# 	0 	Pou
# 	0 	Fab
# ####################################################################################################
# 	1 	RealPlayer®
# 	1 	배달의민족
# 	1 	필수어플가이드
# 	1 	Sports Tracker
# 	1 	날씨 위젯
# 	1 	Predators™
# 	1 	거짓말 탐지기
# 	1 	마리오 브라더스
# 	1 	동화
# 	1 	Google Reader
# 	1 	WWE
# 	1 	Geared
# 	1 	NU
# 	1 	CGV
# 	1 	매치업
# 	1 	Elements
# 	1 	메트로놈
# 	1 	갤럭시
# 	1 	우주전
# 	1 	Bank of America
# 	1 	내 차
# 	1 	SWORD!
# 	1 	위키백과사전
# 	1 	밀리언아서
# 	1 	음성검색
# 	1 	캡
# 	1 	비디오 채팅
# 	1 	모험가
# 	1 	더러운 소리
# 	1 	Locale
# 	1 	Ringdroid
# 	1 	홈플러스
# 	1 	해피포인트
# 	1 	File Manager
# 	1 	Paper Toss
# 	1 	Defender
# 	1 	Scan
# 	1 	성경의 구절
# 	1 	튀다
# 	1 	원기날씨
# 	1 	루팡
# 	1 	Elixir
# 	1 	음성검색​
# 	1 	whisper
# 	1 	Success Story
# 	1 	삼국지를 품다
# 	1 	USA TODAY
# 	1 	심리 테스트
# 	1 	TED
# 	1 	드림걸
# 	1 	insider
# 	1 	구름
# 	1 	날씨 - Weather
# 	1 	Pocket
# 	1 	easyJet
# 	1 	Photo Editor
# 	1 	스머프 빌리지
# 	1 	Line Up
# 	1 	9mm
# 	1 	지도
# 	1 	도그파이트
# 	1 	동물 소리
# 	1 	Fashion Style
# 	1 	Walmart
# 	1 	바코드 스캐너
# 	1 	Telnet
# 	1 	파일 탐색기
# 	1 	Plumber
# 	1 	반딧불
# 	1 	Balloon
# 	1 	심즈 프리플레이
# 	1 	비디오 플레이어
# 	1 	Superuser
# 	1 	러시안 룰렛
# 	1 	mixi
# 	1 	Breaking News!
# 	1 	Flickr
# 	1 	하트
# 	1 	FxCamera
# 	1 	Mutant
# 	1 	The Weather Channel
# 	1 	National Geographic
# 	1 	생일
# 	1 	Timer
# 	1 	RF온라인
# 	1 	1to50®
# 	1 	Snapseed
# 	1 	모터사이클
# 	1 	OnLive
# 	1 	Currency
# 	1 	경찰 등
# 	1 	기억
# 	1 	Photo Studio
# 	1 	사진 꾸미기
# 	1 	손전등
# ####################################################################################################
# 	2 	네이트온UC
# 	2 	Rainy Days
# 	2 	AK-47
# 	2 	Radiant
# 	2 	Radar
# 	2 	Viber
# 	2 	The CATch!
# 	2 	Alchemy
# 	2 	Foursquare
# 	2 	WiMP
# 	2 	핫메일
# 	2 	고양이 소리
# 	2 	Advanced Task Killer
# 	2 	로모 카메라
# 	2 	Farm Frenzy
# 	2 	ABC News
# 	2 	Valor
# 	2 	슈퍼액션 히어로
# 	2 	Argos
# 	2 	조조할인
# 	2 	Bubbles
# 	2 	Theme Park
# 	2 	전쟁의 시대
# 	2 	Backgammon
# 	2 	궁술
# 	2 	Wimbledon
# 	2 	Steam
# 	2 	Adele
# 	2 	Ancestry
# 	2 	Knock Down
# 	2 	다람쥐.
# 	2 	Jobs
# 	2 	ICE
# 	2 	The Guardian
# 	2 	Dead Space™
# 	2 	NOOK
# ####################################################################################################
# 	3 	변환기
# 	3 	Vikings ©
# 	3 	Notepad
# 	3 	Vine
# 	3 	Uninstaller
# 	3 	대한항공
# 	3 	Blogger
# 	3 	Voice Recorder
# 	3 	Thumb
# 	3 	Toss It
# 	3 	PhotoFunia
# 	3 	Jobs+
# 	3 	The Washington Post
# 	3 	심심이
# 	3 	2013프로야구
# 	3 	Dolphin
# 	3 	배터리 위젯
# 	3 	Face Off
# 	3 	Akinator .
# 	3 	Quit Smoking
# 	3 	Hair Salon
# 	3 	틀린그림찾기 !!!
# 	3 	Explorer
# 	3 	Pirates of the Caribbean
# 	3 	Fishing
# 	3 	일화.
# 	3 	지퍼(zipper)
# 	3 	The Economist
# 	3 	Tesco
# 	3 	네이트만화
# 	3 	Piano
# 	3 	대전버스
# 	3 	로빈슨
# 	3 	SoundHound
# 	3 	거울
# 	3 	웃긴 사진
# 	3 	Twitter
# 	3 	미투데이 - me2day
# 	3 	전국버스
# 	3 	SkyDrive
# 	3 	Heart Breaker
# 	3 	YouTube
# 	3 	내 기분
# 	3 	GG
# 	3 	CNET
# 	3 	가짜 전화
# 	3 	음악 다운로드
# 	3 	360
# 	3 	Myspace
# 	3 	드럼
# 	3 	IQ 테스트
# 	3 	My Guitar
# 	3 	Wipeout
# 	3 	사진꾸미기
# 	3 	Horn™
# 	3 	Prison Break
# 	3 	Stopwatch
# 	3 	한붓그리기
# 	3 	고속도로교통정보
# 	3 	Starbucks
# 	3 	연락처+
# ####################################################################################################
# 	4 	배터리
# 	4 	Pandora
# 	4 	Facebook
# 	4 	제노니아3
# 	4 	Tasker
# 	4 	American Airlines
# 	4 	Adobe Reader
# 	4 	Bible
# 	4 	XING
# 	4 	Netflix
# 	4 	Digital Clock
# 	4 	Translate
# 	4 	FOX News
# 	4 	Chess
# 	4 	1km
# 	4 	Rule the Sky
# 	4 	카카오톡 KakaoTalk
# 	4 	건물부수기
# 	4 	네이트온톡
# 	4 	벽돌깨기
# 	4 	이모티콘
# 	4 	Fancy
# 	4 	Exchange Rates
# 	4 	슈퍼배드
# 	4 	불꽃놀이
# 	4 	Grow
# 	4 	Designs
# 	4 	Splatter
# 	4 	Nike+ Running
# 	4 	Best Buy
# 	4 	Goal.com
# 	4 	Total Commander
# 	4 	Photon
# 	4 	Allegro
# 	4 	4pda
# 	4 	Occupation
# 	4 	Shopping List
# 	4 	스톱워치
# 	4 	Pose
# 	4 	Volume Control
# 	4 	말하는 개
# 	4 	GREE
# 	4 	World War™
# 	4 	TETRIS®
# 	4 	조각 그림 맞추기
# 	4 	runtastic
# 	4 	지금 날씨
# 	4 	양궁
# 	4 	The Key
# 	4 	MP3 다운로드
# 	4 	Computer
# 	4 	손전등 ∞
# 	4 	Scarface
# 	4 	Pano
# 	4 	언어 번역기
# 	4 	아임IN
# 	4 	절대음감
# 	4 	조커
# 	4 	친구만들기
# 	4 	참고 사항
# 	4 	Mileage
# 	4 	열린약국찾기
# 	4 	앱순이
# 	4 	on{X}
# 	4 	UNO™
# 	4 	The Verge
# 	4 	Animals
# 	4 	Gunman
# 	4 	Good Morning
# 	4 	Horoscope
# 	4 	상자
# 	4 	Bump
# 	4 	탱그램
# 	4 	Spirits
# 	4 	Avatar
# ####################################################################################################
# 	5 	Roman Empire
# 	5 	Jewels
# 	5 	Wish
# 	5 	아스트로 파일 관리자
# 	5 	옥션
# 	5 	Drinking Water
# 	5 	수평계
# 	5 	나는꼼수다
# 	5 	Spades
# 	5 	Take me Home
# 	5 	Cut the Rope
# 	5 	Mute.
# 	5 	KAYAK
# 	5 	اهم 1000 كلمة انجليزية
# 	5 	Bartender
# 	5 	Pilot!
# 	5 	SBS 뉴스
# 	5 	배관공
# 	5 	2012프로야구
# 	5 	날려버리다
# 	5 	골프스타
# 	5 	스타 걸
# 	5 	Captain America
# 	5 	TuneIn Radio
# 	5 	Target
# 	5 	판도라TV
# 	5 	음악 플레이어
# 	5 	SCRABBLE
# 	5 	차이를 발견
# 	5 	Last.fm
# 	5 	TMZ
# 	5 	라인 LINE
# 	5 	BBC News
# 	5 	Shopping list
# 	5 	Thousand+
# 	5 	Hit It!
# 	5 	퍼즐앤드래곤
# 	5 	환율 계산기
# 	5 	DC Comics
# 	5 	Tango
# 	5 	Darts
# 	5 	더비데이즈
# 	5 	MBC 라디오 mini
# 	5 	MBC News
# 	5 	Slot Machine
# 	5 	그림을 그릴
# 	5 	연합뉴스
# 	5 	일기 예보
# 	5 	Congress
# 	5 	Bejeweled® 2
# 	5 	Trap!
# 	5 	Minecraft - Pocket Edition
# 	5 	Colors
# 	5 	총
# 	5 	Cloudy
# 	5 	Skype
# 	5 	من سيربح المليون 2013
# 	5 	드래곤 볼 Z
# 	5 	iReader
# 	5 	Bubble
# 	5 	Find Something
# 	5 	Soccer
# 	5 	숨은 그림 찾기
# 	5 	Commando
# 	5 	Banner
# ####################################################################################################
# 	6 	삼성카드
# 	6 	이미지패러디
# 	6 	Closer
# 	6 	Safeway
# 	6 	맨 인 블랙 3
# 	6 	톱 모델
# 	6 	패션 스토리™
# 	6 	블레이드 마스터
# 	6 	데몬헌터
# 	6 	Plan B
# 	6 	Freecell
# 	6 	오목+
# 	6 	이게 뭐야?
# 	6 	Tumblr
# 	6 	공포의 집
# 	6 	Memory
# 	6 	사진 합성
# 	6 	매직트리
# 	6 	اهم 100 جملة انجليزية
# 	6 	축구선수
# 	6 	MONOPOLY
# 	6 	Kindle
# 	6 	United Airlines
# 	6 	4shared
# 	6 	패션 아이콘
# 	6 	가로세로 낱말맞추기
# 	6 	Dice
# 	6 	AIM
# 	6 	엠넷(Mnet)
# 	6 	네이버 - Naver
# 	6 	QQ
# 	6 	PayPal
# 	6 	제노니아4
# 	6 	Death Note
# 	6 	Path
# 	6 	박가네
# 	6 	Task Manager
# 	6 	슈터
# 	6 	메신저
# 	6 	Swiss Army Knife
# 	6 	Doodle Jump
# 	6 	매직데이
# 	6 	LinkedIn
# 	6 	기상청 날씨
# 	6 	Battery Indicator
# 	6 	My Country
# 	6 	리버시
# 	6 	Snake
# 	6 	Slot Machine +
# 	6 	응급상황 대처방법
# 	6 	Fireworks
# 	6 	Millionaire
# 	6 	Plants vs. Zombies™
# 	6 	어린이 게임
# 	6 	영화 퀴즈
# 	6 	피싱마스터
# 	6 	우주 식민지
# 	6 	White Noise
# 	6 	微博
# 	6 	Twitvid
# 	6 	Firefox
# ####################################################################################################
# 	7 	Yellow Pages
# 	7 	초음속 ™
# 	7 	Lose It!
# 	7 	Drop
# 	7 	Solitaire
# 	7 	Diversion
# 	7 	메탈슬러그
# 	7 	Engadget
# 	7 	Solo
# 	7 	곰TV
# 	7 	Winamp
# 	7 	twicca
# 	7 	뇌구조 테스트
# 	7 	Dictionary
# 	7 	Abduction!
# 	7 	K
# 	7 	다국어 번역기
# 	7 	Apparatus
# 	7 	원시인이
# 	7 	Monsters
# 	7 	Angry Birds
# 	7 	친필
# 	7 	Hangman
# 	7 	MASH
# ####################################################################################################
# 	8 	NOS
# 	8 	Three
# 	8 	탁구
# 	8 	Word Search
# 	8 	ดู Manga : อ่านการ์ตูนออนไลน์
# 	8 	조용한 카메라
# 	8 	SoundHound ∞
# 	8 	어메이징 스파이더맨
# 	8 	저격병
# 	8 	First Aid
# 	8 	Fruit Ninja
# 	8 	RunKeeper
# 	8 	Sudoku
# 	8 	일렉트릭 기타
# 	8 	SBS 고릴라
# 	8 	CANAL+
# 	8 	Vimeo
# 	8 	Pizza Hut
# 	8 	Phono
# 	8 	Yesterday
# 	8 	WolframAlpha
# 	8 	TAMAGO
# 	8 	Spotify
# 	8 	다음 - Daum
# 	8 	시간표
# 	8 	My Prayer - صلاتي
# 	8 	11번가
# 	8 	Roller Coaster
# 	8 	Banjo
# 	8 	에브리온TV
# 	8 	싸이월드
# 	8 	Layar
# 	8 	Notes
# 	8 	Sanity
# 	8 	테니스
# 	8 	지구
# 	8 	PGA TOUR
# 	8 	오목
# 	8 	배구
# 	8 	GYRO
# 	8 	Assistant
# 	8 	불가능한 게임
# 	8 	LauncherPro
# 	8 	인터넷 라디오
# 	8 	Battleship
# 	8 	StumbleUpon
# 	8 	PhotoWonder
# 	8 	Real Racing
# 	8 	Diner Dash
# 	8 	Hearts!
# 	8 	Adobe AIR
# 	8 	사진 효과
# 	8 	Weather
# 	8 	배경화면
# 	8 	멜론
# 	8 	Guns
# 	8 	동물의 소리
# 	8 	Aztec
# 	8 	FlashLight
# 	8 	볼륨 조절
# 	8 	삼국지 디펜스
# 	8 	The Sims™ 3
# 	8 	Emoticons
# 	8 	미로 게임
# 	8 	기념일 관리
# 	8 	담배 라이터
# 	8 	폭풍
# 	8 	Google 번역
# 	8 	단어 검색
# 	8 	Pancakes!!!
# 	8 	Temple Run
# 	8 	10000000
# 	8 	Dwell
# ####################################################################################################
# 	9 	줌 카메라
# 	9 	네이트
# 	9 	Yelp
# 	9 	Revolver
# 	9 	Dictionary.com
# 	9 	배터리 정보
# 	9 	Paint
# 	9 	screenshot
# 	9 	Gmail
# 	9 	XMS
# 	9 	pixiv
# 	9 	³
# 	9 	Bingo
# 	9 	hike
# 	9 	Hi There
# 	9 	미니펫
# 	9 	Rebuild
# 	9 	지하철 노선도
# 	9 	Thermometer
# 	9 	에어펭귄
# 	9 	Marvel Comics
# 	9 	폴라로이드 카메라
# 	9 	푸딩얼굴인식
# 	9 	Root Explorer
# 	9 	Overkill
# 	9 	CBS News
# 	9 	Equalizer
# 	9 	Shazam
# 	9 	Google+
# 	9 	파일 관리자
# 	9 	WHERE
# 	9 	통화 녹음
# 	9 	미로!
# 	9 	Cut It!
# 	9 	메모장
# 	9 	LED Light
# 	9 	Warship
# 	9 	Rhapsody
# 	9 	솔리테어
# 	9 	스마트청구서
# 	9 	Vignette
# 	9 	Calculator++
# 	9 	Love Life
# 	9 	Okey
# 	9 	Earthquake!
# 	9 	500px
# 	9 	지하철 내비게이션
# 	9 	HomeWork
# 	9 	deciBel
# 	9 	Bing
# 	9 	SoundCloud
# 	9 	IM+
# 	9 	WordPress
# 	9 	Shopper
# 	9 	Vector

# %%
nClusters = 20

kms = KMeans(n_clusters=nClusters)
kms.fit(dftemphead2)

print kms.cluster_centers_
print kms.labels_[:nClusters]

plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.
# Out:
# [[-0.82009733 -0.96961092 -0.88509031 ..., -0.6938349  -1.09836838
#   -0.90468734]
#  [ 0.15923974  0.01546641 -0.08282623 ..., -0.18397408  0.73952953
#    0.11198766]
#  [-1.03681765 -0.63251091 -0.78682149 ...,  1.09909845 -1.0194947
#   -0.21241214]
#  ...,
#  [ 0.49210823 -0.23081207  0.26377579 ..., -0.37932829  2.30254947
#   -1.13009719]
#  [-1.05337105  0.28317203 -0.40757259 ..., -0.78842457 -0.53822703
#    0.65128351]
#  [-0.19189239  0.21636877 -0.29348499 ...,  0.54575354  0.20843173
#    0.64800111]]
# [ 0  1  1  9  9  9  3 13  1 19 16  1  6 19 18 14 16  8  3 18]

# %%
nClusters = 30

kms = KMeans(n_clusters=nClusters)
kms.fit(dftemphead2)

print kms.cluster_centers_
print kms.labels_[:nClusters]

plot_2D(dftemphead2, kms.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.  

pca = PCA(n_components=2, whiten=True).fit(dftemphead2)
df_pca = pca.transform(dftemphead2)

kms2 = KMeans(n_clusters=nClusters)
kms2.fit(df_pca)

plot_2D(df_pca, kms2.labels_, range(len(set(kms2.labels_)))) # 클러스터링 한 결과.
# Out:
# [[  5.88102703e-01   3.23664772e-01   1.00498014e+00 ...,  -1.48834654e-01
#    -5.97910320e-01  -3.38824355e-01]
#  [ -2.87500837e-01  -8.31672045e-01  -3.20631953e-01 ...,   6.28543956e-01
#    -3.44808826e-01  -4.20279968e-01]
#  [ -2.03538942e-04  -1.88508766e-01  -1.98210792e-02 ...,  -7.14926154e-01
#     2.39010535e-01  -1.98941414e-01]
#  ...,
#  [  8.57717222e-01   4.63352122e-01   5.22877524e-01 ...,   3.99471598e-01
#     1.68213608e+00   8.77603907e-01]
#  [  1.64976500e-01  -1.35571786e-01   1.54611191e-02 ...,   1.80243553e-01
#     9.17575031e-01   1.84210762e-01]
#  [ -4.36478028e-01   6.84110559e-01  -4.57885813e-01 ...,  -1.52910737e-01
#     1.40771686e-01   9.90444944e-01]]
# [24  5 28 24 24 24  0  6  2 27 12  5 14 26 26  9 12 11  0 26  4 22 13 25 27
#   4 10 25 14 23]
