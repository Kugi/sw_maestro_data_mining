# %%
pwd
# Out:
# u'/Users/jeongmingi/sw_maestro_data_mining/Min/3regression'

# %%
import pickle
apps = pickle.load(file('data/app_info2.df'))
uapp = pickle.load(file('data/user_app.df'))

# %%
uapp.keys()
# Out:
# Index([create_date, update_date, user_id, entity_id, usage, is_deleted], dtype=object)

# %%
app = uapp.ix[uapp['entity_id']==1527791]

# %%
app.create_date[:3].values
# Out:
# array([20130222053030, 20130604154517, 20130307114929])

# %%
apps.keys()
# Out:
# Index([id, date, create_date, update_date, genre, cate, score, name, price, developer, intro, size, ver, company, code, app_cate, company_id, download_num, rate_num_all], dtype=object)

# %%
apps.ix[apps['id']==1527791].name
# Out:
# 256277    카카오톡 KakaoTalk
# Name: name, dtype: object

# %%
hist_app = app[['create_date', 'update_date', 'usage']]

# %%
# %pylab inline
hist_app.hist()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['clf']
# `%pylab --no-import-all` prevents importing * from pylab and numpy
# array([[<matplotlib.axes.AxesSubplot object at 0x10e06df50>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x170ff2590>]], dtype=object)

# %%
app
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118948 entries, 240 to 10616375
# Data columns (total 6 columns):
# create_date    118948  non-null values
# update_date    118948  non-null values
# user_id        118948  non-null values
# entity_id      118948  non-null values
# usage          118948  non-null values
# is_deleted     115617  non-null values
# dtypes: int64(5), object(1)

# %%
app['create_date'] = app['create_date']//1000000
app['update_date'] = app['update_date']//1000000

# %%
keys = app['create_date'].unique()

# %%
import numpy as np
import pandas as pd

# %%
b = app.groupby('create_date')

# %%
for name, group in b:
    print (name)
    print (group)
# Out:
# 20130221
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 75788 to 10592914
# Data columns (total 6 columns):
# create_date    201  non-null values
# update_date    201  non-null values
# user_id        201  non-null values
# entity_id      201  non-null values
# usage          201  non-null values
# is_deleted     201  non-null values
# dtypes: int64(5), object(1)
# 20130222
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32758 entries, 240 to 10616110
# Data columns (total 6 columns):
# create_date    32758  non-null values
# update_date    32758  non-null values
# user_id        32758  non-null values
# entity_id      32758  non-null values
# usage          32758  non-null values
# is_deleted     32758  non-null values
# dtypes: int64(5), object(1)
# 20130223
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4599 entries, 5296 to 10615035
# Data columns (total 6 columns):
# create_date    4599  non-null values
# update_date    4599  non-null values
# ...

# %%
data1 = []
for name, group in b:
    name = int(name)
    temp = {'date' : name, 'cnt' : int(len(group))}
    data1.append(temp)

# %%
data1[30:40]
# Out:
# [{'cnt': 292, 'date': 20130326},
#  {'cnt': 315, 'date': 20130327},
#  {'cnt': 334, 'date': 20130328},
#  {'cnt': 342, 'date': 20130329},
#  {'cnt': 403, 'date': 20130330},
#  {'cnt': 91, 'date': 20130331},
#  {'cnt': 386, 'date': 20130401},
#  {'cnt': 434, 'date': 20130402},
#  {'cnt': 330, 'date': 20130403},
#  {'cnt': 280, 'date': 20130404}]

# %%
pd_data1 = pd.DataFrame(data1)
a = pd_data1.date.values
b = pd_data1.cnt.values
plt.scatter(a, b)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

b_ = pd.DataFrame(b)
a_ = pd.DataFrame(a)
plt.scatter(a_, b_)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(a_, b_) # fit(attribut, label)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
[[0, 2], [1, 4], [2, 7]]
# Out:
# [[0, 2], [1, 4], [2, 7]]

# %%
#월(0): 전체 어플 100개 다운, 공휴일아닌일, weekdata - 우리 어플 20개 다운, 화(1): 전체 어플 290개 다운 - 우리 어플 40개 다운, ...  
clf.fit([[0, 100], [1, 290], [2, 300], [3, 280], [4, 500], [5,450], [6,200]], [20, 40, 40, 50, 70, 64, 30])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
import pandas as pd
dd = [[0, 100], [1, 290], [2, 300], [3, 280], [4, 500], [5,450], [6,200]]
pd.DataFrame(dd).shape
# Out:
# (7, 2)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['clf']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
plt.scatter([0,1,2,3,4,5,6], [20, 40, 40, 50, 70, 64, 30])
plt.axis('tight')
plt.plot([0, 100], [0, 100], '--k')

# %%
clf.predict([[0, 200], [1, 390], [2, 400], [3, 280], [4, 300], [5,350], [6,50]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-626355f809a4> in <module>()
# ----> 1 clf.predict([[0, 200], [1, 390], [2, 400], [3, 280], [4, 300], [5,350], [6,50]])
#
# AttributeError: 'function' object has no attribute 'predict'

# %%
a_.shape, b_.shape
# Out:
# ((151, 1), (151, 1))

# %%
a[:3], b[:3]
# Out:
# (array([20130221, 20130222, 20130223]), array([  201, 32758,  4599]))

# %%
a_[:3], b_[:3]
# Out:
# (          0
# 0  20130221
# 1  20130222
# 2  20130223,
#         0
# 0    201
# 1  32758
# 2   4599)

# %%
predicted = clf.predict(a_)
plt.scatter(b_, predicted)
plt.plot([0, 10000], [0, 10000], '--k')
plt.xlabel('True')
plt.ylabel('Predicted')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-0da3c3a7d55f> in <module>()
# ----> 1 predicted = clf.predict(a_)
#       2 plt.scatter(b_, predicted)
#       3 plt.plot([0, 10000], [0, 10000], '--k')
#       4 plt.xlabel('True')
#       5 plt.ylabel('Predicted')
#
# AttributeError: 'function' object has no attribute 'predict'

# %%
from sklearn.tree import DecisionTreeRegressor
# Instantiate the model, fit the results, and scatter in vs. out

clf2 = DecisionTreeRegressor()
clf2.fit(a_, b_)
# Out:
# DecisionTreeRegressor(compute_importances=False, criterion='mse',
#            max_depth=None, max_features=None, min_density=0.1,
#            min_samples_leaf=1, min_samples_split=2, random_state=None)

# %%
predicted2 = clf2.predict(a_)
plt.scatter(b_, predicted2)
plt.axis('tight')
plt.plot([0, 10000], [0, 10000], '--k')

plt.xlabel('True count')
plt.ylabel('Predicted count')

# %%
i = 20130801
k = []

# %%
for ii in range(31):
    k.append(i+ii)
k[:3]
# Out:
# [20130801, 20130802, 20130803]

# %%
test_ = pd.DataFrame(k)

# %%
k = clf2.predict(test_)

# %%
clf2.predict(pd.DataFrame([20130730, 20130731, 20131201]))
# Out:
# array([ 1747.,   505.,   505.])

# %%
clf2.predict(pd.DataFrame([20130701, 20130702]))
# Out:
# array([ 560.,  562.])

# %%
b_[:3]
# Out:
#        0
# 0    201
# 1  32758
# 2   4599

# %%
a_.shape, b_.shape
# Out:
# ((151, 1), (151, 1))

# %%
plt.scatter(test_, k)

# %%
[a_[119:], b_[:3]]
# Out:
# [            0
# 119  20130630
# 120  20130701
# 121  20130702
# 122  20130703
# 123  20130704
# 124  20130705
# 125  20130706
# 126  20130707
# 127  20130708
# 128  20130709
# 129  20130710
# 130  20130711
# 131  20130712
# 132  20130713
# 133  20130714
# 134  20130715
# 135  20130716
# 136  20130717
# 137  20130718
# 138  20130719
# 139  20130720
# 140  20130721
# 141  20130722
# 142  20130723
# 143  20130724
# 144  20130725
# 145  20130726
# 146  20130727
# 147  20130728
# 148  20130729
# 149  20130730
# 150  20130731,
#         0
# 0    201
# 1  32758
# 2   4599]

# %%
b_
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 150
# Data columns (total 1 columns):
# 0    151  non-null values
# dtypes: int64(1)

# %%
from sklearn import linear_model
clf = linear_model.LassoLars(alpha=.1)
clf.fit([[0, 0], [1, 1]], [0, 1])
# Out:
# LassoLars(alpha=0.1, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      precompute='auto', verbose=False)

# %%
day_calc_app_info = app.copy()
su = day_calc_app_info.pop('update_date')
sd = day_calc_app_info.pop('create_date')
sa = aliveDay(su,sd)
day_calc_app_info.insert(0,sa.name,sa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-470695d1864d> in <module>()
#       2 su = day_calc_app_info.pop('update_date')
#       3 sd = day_calc_app_info.pop('create_date')
# ----> 4 sa = aliveDay(su,sd)
#       5 day_calc_app_info.insert(0,sa.name,sa)
#
# NameError: name 'aliveDay' is not defined
