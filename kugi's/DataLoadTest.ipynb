# %%
# %pylab inline
import pylab as pl
import numpy as np
import pandas as pd
from pandas import DataFrame
from sklearn.datasets import load_svmlight_file

import pickle
import json
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# ### <br>
# user_gender.dat<br>
# 성별 데이터<br>
# 여성: 1<br>
# 남성: 2

# %%
# %time _ = gender_x, gender_y = load_svmlight_file('user_gender.dat')
print (gender_x.shape, gender_y.shape)
# Out:
# Wall time: 8.51 s
# ((46984, 52600), (46984,))

# %% [markdown]
# ### <br>
# user_age.dat<br>
# 나이 데이터<br>
# 10대: 1<br>
# 20대: 2<br>
# 30대: 3<br>
# 40대: 4<br>
# 50대: 5

# %%
# %time _ = age_x, age_y = load_svmlight_file('user_age.dat')
print (age_x.shape, age_y.shape)
# Out:
# Wall time: 7.63 s
# ((42934, 49683), (42934,))

# %% [markdown]
# ### <br>
# user_prov.dat<br>
# 지역 데이터<br>

# %%
# %time _ = prov_x, prov_y = load_svmlight_file('user_prov.dat')
print (prov_x.shape, prov_y.shape)
# Out:
# Wall time: 9.5 s
# ((47074, 44620), (47074,))

# %% [markdown]
# ### <br>
# prov.dat<br>
# 지역 인덱스 데이터<br>

# %%
# %time _ = provlist = pickle.load(file('prov.dat'))
print len(provlist)
print "\n".join(set(provlist))
# Out:
# Wall time: 12 ms
# 289
# Ventspils pilsēta
# Stavropol Krai
# 아브루초 주
# 경상남도
# BC
# Sindh
# Region I
# Can Tho
# 부리람 주
# Veneto
# East Kalimantan
# BW
# 테르노필 주
# WP
# Kamphaeng Phet
# 전라남도
# BA
# Región de Valparaíso
# 이스트라 주
# WA
# RS
# Riyadh Province
# 전북
# 뜨랏 주
# 강원
# Baghdād
# 콘깬 주
# North Sumatra
# 전라북도
# Roi Et
# Kırklareli Province
# RN
# Rīgas pilsēta
# RJ
# Central Visayas
# 하왈리
# Lazio
# Malaka
# Balqa
# 충칭 시
# Phnom Penh
# 메디나 주
# Bekaa
# GE
# 스타브로폴 지방
# Samut Prakan
# Kyiv city
# Araucania
# Phayao
# 인천
# 페이드라루아르
# 흐로드나 주
# ON
# Šiauliai County
# OH
# 서울
# Penang
# 나가노 현
# Al Jowf
# CHIH
# 프를리스 주
# Central Luzon
# 사라토프
# PACA
# Eastern Province
# 미야자키 현
# 충청남도
# 수랏타니 주
# Al Qassim
# Jeollabuk-do
# Saint Petersburg
# CL
# Chechnya
# Lamphun
# Udon Thani
# HH
# Phatthalung
# Syddanmark
# 부산
# Ho Chi Minh City
# Phang-nga
# Alajuela
# 충북
# Chiang Rai
# 전남
# PR
# Cundinamarca
# AG
# Khon Kaen
# FL
# BB
# 칼루가 주
# 경기,화성시
# PB
# Hubei
# PA
# Central Division
# 박닌 성
# ...

# %%
type(provlist)
# Out:
# list

# %%
filename = "user_app.df"
user_app = 0

with open(filename, 'rb') as user_app_file:
    # %time _ = user_app = pickle.load(user_app_file)

# %% [markdown]
# ### <br>
# user_app.df<br>
# 앱 설치 정보 데이터

# %%
user_app?

# %%
#%time _ = user_app = pickle.load(file('user_app.df'))
print len(user_app)
print "\n".join(set(user_app))
# Out:
# 10616409
# update_date
# entity_id
# create_date
# user_id
# usage
# is_deleted

# %%
# %time _ = entityid_featureid = pickle.load(file('entityid_featureid.pkl'))
print len(entityid_featureid)
print "\n".join(set(entityid_featureid))
# Out:
# Wall time: 866 ms
# 52600
# 1658496
# 1658497
# 1774518
# 1658495
# 1475833
# 1658493
# 1658490
# 1774516
# 1774517
# 1658498
# 1774515
# 1420952
# 1774519
# 1770600
# 1420959
# 1424242
# 1603009
# 1603008
# 1474124
# 1474125
# 1795333
# 1603004
# 1603007
# 1603006
# 1603001
# 1603000
# 1603003
# 1603002
# 1751014
# 1458703
# 1458705
# 1751010
# 1458707
# 1689407
# 1698374
# 1698371
# 1698370
# 1650467
# 1475838
# 1689212
# 1664706
# 1689401
# 1797549
# 1633342
# 1691965
# 1649503
# 1691967
# 1649501
# 1691961
# 1649507
# 1691963
# 1691962
# 1670772
# 1649509
# 1529343
# 1690615
# 1529341
# 1529340
# 1690610
# 1529349
# 1529348
# 1673224
# 1689409
# 1618119
# 1797541
# 1524059
# 1771559
# 1771558
# 1497922
# 1497925
# 1497924
# 1771551
# 1771550
# 1771553
# 1771552
# 1771555
# 1771554
# 1641081
# 1771556
# 1604259
# 1604258
# 1651329
# 1604255
# 1604254
# 1604257
# 1604256
# 1604251
# 1604250
# 1604253
# 1604252
# 1657449
# 1650498
# 1605124
# 1605125
# 1605126
# 1657447
# 1605120
# ...
