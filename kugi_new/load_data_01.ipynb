# %%
# %pylab inline
import pickle
import pylab as pl
import numpy as np
import pandas as pd
from sklearn.datasets import load_svmlight_file

from pandas import DataFrame
import json
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
provlist = pickle.load(file('prov.dat'))

# %%
for i in range (0, len(provlist)):
    print i, provlist[i] + '\n'
# Out:
# 0 Ventspils pilsēta
#
# 1 CAMP
#
# 2 아브루초 주
#
# 3 경상남도
#
# 4 BC
#
# 5 Sindh
#
# 6 Region I
#
# 7 부리람 주
#
# 8 경기,화성시
#
# 9 Veneto
#
# 10 East Kalimantan
#
# 11 BW
#
# 12 테르노필 주
#
# 13 WP
#
# 14 Kamphaeng Phet
#
# 15 전라남도
#
# 16 BA
#
# 17 Región de Valparaíso
#
# 18 이스트라 주
#
# 19 WA
#
# 20 RS
#
# 21 전북
#
# 22 뜨랏 주
#
# 23 강원
#
# 24 Nairobi
#
# 25 PA
#
# 26 North Sumatra
#
# 27 전라북도
#
# 28 Roi Et
#
# 29 Central Division
#
# 30 RN
#
# 31 Rīgas pilsēta
#
# 32 BY
#
# 33 RJ
#
# 34 Central Visayas
#
# 35 Istanbul
#
# 36 하왈리
#
# 37 Lazio
#
# 38 Malaka
#
# 39 Balqa
#
# 40 충칭 시
#
# 41 Phnom Penh
#
# 42 Bekaa
#
# 43 GE
#
# 44 스타브로폴 지방
#
# 45 Samut Prakan
#
# 46 Kyiv city
#
# 47 Araucania
#
# 48 Phayao
#
# 49 인천
#
# 50 페이드라루아르
#
# 51 흐로드나 주
#
# 52 ON
#
# 53 TN
#
# 54 Šiauliai County
#
# 55 OH
#
# 56 서울
#
# 57 Penang
#
# 58 나가노 현
#
# 59 محافظة كانتشانابوري
#
# 60 Lorraine
#
# 61 Central Luzon
#
# 62 사라토프
#
# 63 PACA
#
# 64 Eastern Province
#
# 65 미야자키 현
#
# 66 충청남도
#
# 67 수랏타니 주
#
# 68 Al Qassim
#
# ...

# %%
user_gender_x, user_gender_y = load_svmlight_file('user_gender.dat')
print user_gender_x.shape, user_gender_y.shape
# Out:
# (46984, 52600) (46984,)

# %%
print user_gender_x
# Out:
#   (0, 1748)	1.0
#   (0, 2796)	1.0
#   (0, 2853)	1.0
#   (0, 6491)	1.0
#   (0, 7834)	1.0
#   (0, 7903)	1.0
#   (0, 8007)	1.0
#   (0, 8133)	1.0
#   (0, 8165)	1.0
#   (0, 8677)	1.0
#   (0, 8679)	1.0
#   (0, 8700)	1.0
#   (0, 9114)	1.0
#   (0, 9201)	1.0
#   (0, 9769)	1.0
#   (0, 9775)	1.0
#   (0, 9928)	1.0
#   (0, 11310)	1.0
#   (0, 11781)	1.0
#   (0, 15803)	1.0
#   (0, 16638)	1.0
#   (0, 16712)	1.0
#   (0, 16948)	1.0
#   (0, 18307)	1.0
#   (0, 18356)	1.0
#   :	:
#   (46982, 50298)	1.0
#   (46982, 51140)	1.0
#   (46983, 6262)	1.0
#   (46983, 8165)	1.0
#   (46983, 8680)	1.0
#   (46983, 9114)	2.0
#   (46983, 9412)	2.0
#   (46983, 11261)	1.0
#   (46983, 13637)	2.0
#   (46983, 15113)	1.0
#   (46983, 15803)	1.0
#   (46983, 19217)	1.0
#   (46983, 20541)	2.0
#   (46983, 22829)	1.0
#   (46983, 22923)	1.0
#   (46983, 26677)	1.0
#   (46983, 28743)	1.0
#   (46983, 31826)	1.0
#   (46983, 33762)	2.0
#   (46983, 36631)	1.0
#   (46983, 42936)	2.0
#   (46983, 47344)	1.0
#   (46983, 48943)	1.0
# ...

# %%
#user_app_x, user_app_y = load_svmlight_file('user_app.df')
#print user_app_x.shape, user_app_y.shape

# %%
user_age_x, user_age_y = load_svmlight_file('user_age.dat')
print user_age_x.shape, user_age_y.shape
# Out:
# (42934, 49683) (42934,)

# %%
#user_age_x_list = user_age_x.toarray()
user_age_y_list = user_age_y.tolist()

# %%
print user_age_x.shape
print user_age_x
# Out:
# (42934, 49683)
#   (0, 1650)	1.0
#   (0, 2637)	1.0
#   (0, 2691)	1.0
#   (0, 7417)	1.0
#   (0, 7481)	1.0
#   (0, 7585)	1.0
#   (0, 7706)	1.0
#   (0, 7736)	1.0
#   (0, 8225)	1.0
#   (0, 8247)	1.0
#   (0, 8635)	1.0
#   (0, 8721)	1.0
#   (0, 9255)	1.0
#   (0, 9397)	1.0
#   (0, 10702)	1.0
#   (0, 11153)	1.0
#   (0, 11481)	1.0
#   (0, 14743)	1.0
#   (0, 14923)	1.0
#   (0, 15078)	1.0
#   (0, 15700)	1.0
#   (0, 15768)	1.0
#   (0, 15993)	1.0
#   (0, 17278)	1.0
#   (0, 17325)	1.0
#   :	:
#   (42932, 47505)	1.0
#   (42932, 48303)	1.0
#   (42933, 5945)	1.0
#   (42933, 7736)	1.0
#   (42933, 8228)	1.0
#   (42933, 8635)	2.0
#   (42933, 8919)	2.0
#   (42933, 10654)	1.0
#   (42933, 12883)	2.0
#   (42933, 14279)	1.0
#   (42933, 14923)	1.0
#   (42933, 18151)	1.0
#   (42933, 19392)	2.0
#   (42933, 21576)	1.0
#   (42933, 21665)	1.0
#   (42933, 25189)	1.0
#   (42933, 25699)	1.0
#   (42933, 27134)	1.0
#   (42933, 30034)	1.0
#   (42933, 31877)	2.0
#   (42933, 34612)	1.0
#   (42933, 40555)	2.0
# ...

# %%
pickle.load?

# %%
user_prov_x, user_prov_y = load_svmlight_file('user_prov.dat')

# %%
print user_prov_x
# Out:
#   (0, 1494)	1.0
#   (0, 2357)	1.0
#   (0, 2406)	1.0
#   (0, 4814)	1.0
#   (0, 5389)	1.0
#   (0, 5468)	1.0
#   (0, 6648)	1.0
#   (0, 6740)	1.0
#   (0, 6856)	1.0
#   (0, 6881)	1.0
#   (0, 7311)	1.0
#   (0, 7333)	1.0
#   (0, 7669)	1.0
#   (0, 7752)	1.0
#   (0, 8239)	1.0
#   (0, 8376)	1.0
#   (0, 9059)	1.0
#   (0, 9526)	1.0
#   (0, 9566)	1.0
#   (0, 9970)	1.0
#   (0, 10267)	1.0
#   (0, 13383)	1.0
#   (0, 14095)	1.0
#   (0, 14171)	1.0
#   (0, 14377)	1.0
#   :	:
#   (47073, 15379)	1.0
#   (47073, 15614)	11.0
#   (47073, 16699)	1.0
#   (47073, 17852)	3.0
#   (47073, 17960)	1.0
#   (47073, 22494)	3.0
#   (47073, 22929)	1.0
#   (47073, 26204)	6.0
#   (47073, 27315)	11.0
#   (47073, 27563)	2.0
#   (47073, 27602)	1.0
#   (47073, 28316)	3.0
#   (47073, 28396)	1.0
#   (47073, 28843)	1.0
#   (47073, 31369)	1.0
#   (47073, 31378)	3.0
#   (47073, 33193)	3.0
#   (47073, 35722)	7.0
#   (47073, 37938)	1.0
#   (47073, 41497)	1.0
#   (47073, 41689)	1.0
#   (47073, 41750)	1.0
#   (47073, 43607)	1.0
# ...

# %%
p
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-163-b6312cc6f98d> in <module>()
# ----> 1 pd.load('user_app.df')
#
# C:\Users\Kugi\AppData\Local\Enthought\Canopy32\System\lib\site-packages\pandas\core\common.pyc in load(path)
#    1583     try:
#    1584         with open(path,'rb') as fh:
# -> 1585             return pickle.load(fh)
#    1586     except:
#    1587         if not py3compat.PY3:
#
# MemoryError:

# %%
user_gender_x?

# %%
temp.to
# Out:
# <47074x1 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>

# %%
#pickle.loads('user_app.df')
DataFrame.load('user_app.df')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-168-05ec0e620258> in <module>()
#       1 #pickle.loads('user_app.df')
# ----> 2 DataFrame.load('user_app.df')
#
# C:\Users\Kugi\AppData\Local\Enthought\Canopy32\System\lib\site-packages\pandas\core\generic.pyc in load(cls, path)
#      30     @classmethod
#      31     def load(cls, path):
# ---> 32         return com.load(path)
#      33
#      34     #----------------------------------------------------------------------
#
# C:\Users\Kugi\AppData\Local\Enthought\Canopy32\System\lib\site-packages\pandas\core\common.pyc in load(path)
#    1583     try:
#    1584         with open(path,'rb') as fh:
# -> 1585             return pickle.load(fh)
#    1586     except:
#    1587         if not py3compat.PY3:
#
# MemoryError:

# %%
pd.read_csv('user_app.df')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-169-6e480e797eb1> in <module>()
# ----> 1 pd.read_csv('user_app.df')
#
# C:\Users\Kugi\AppData\Local\Enthought\Canopy32\System\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze)
#     399                     buffer_lines=buffer_lines)
#     400
# ...
